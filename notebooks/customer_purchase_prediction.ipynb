# %% [markdown]
# # Predictive Analysis using sci-kit-learn
# ## *DAV 5400 Project 4*

# %% [markdown]
# ## Phase I: Data Acquisition, Data Preparation & Exploratory Data Analysis

# %% [markdown]
# ----------------------------------------------------
# ### 1. Introduction:
#
# The main purpose of this project is to develop an effective and robust predictive model that can predict whether a customer is willing to purchase a new product or not. By using the previous customer's data this model aims to provide insights into customers purchasing behaviour, which helps the company to optimize its sales and marketing strategies. With this predictive model, the company can also strengthen its relationship with the already existing customers which might help them in the long run. An accurate prediction model also helps the company to focus their marketing efforts on a specific group of customers which saves their investment of time and money on all other categories. The sales team can also increase their efficiency and effectiveness on these potential customers. The predictive model serves as a valuable tool for strategic decision-making, enabling the company to allocate resources more efficiently, prioritize customer segments, and optimize product offerings based on anticipated demand.

# %% [markdown]
# ----------------------------------------------------------------
# ### 2. Data Loading

# %% [markdown]
# #### Step 1: Import Python Libraries
#
# - Import all libraries that are required for our analysis, such as Data Loading, Statistical analysis, Visualization etc.
#
# - __Pandas__ and __Numpy__ have been used for __Data Manipulation__ and __numerical Calculations__.
#
# - __Matplotlib__ and __Seaborn__ have been used for __Data visualizations__.
#
# - GitHub source link:https://raw.githubusercontent.com/Nikkat-Afrin/DAV-5400/master/Project%204%20DATA.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import functools as _ft
if not getattr(sns, "_palette_hue_patch", False):
    for _f in ("countplot","barplot","boxplot","violinplot","stripplot","swarmplot","pointplot","boxenplot"):
        _o = getattr(sns, _f, None)
        if _o is None:
            continue
        def _w(*a, _o=_o, **k):
            if k.get("palette") is not None and "hue" not in k:
                if "x" in k:
                    k["hue"] = k["x"]
                elif "y" in k:
                    k["hue"] = k["y"]
                k.setdefault("legend", False)
            return _o(*a, **k)
        setattr(sns, _f, _ft.wraps(_o)(_w))
    sns._palette_hue_patch = True
#to ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Step 2: Reading Dataset
# - Here, we are using the __read_csv()__ function, to convert the data into the panda's data frame.
# - The data is stored in the DataFrame __data__.

# %%
# load the data set
df = pd.read_csv("data/Project4_Data.csv")
df
# Out:
#       TARGET  loyalty      ID  age  city  prod_A  type_A  type_B  prod_B  \
# 0          Y       99      77   66     2       0       0       0       0
# 1          Y        1     159   45     2       1       3       3       1
# 2          Y        1     220   42     2       1       3       6       1
# 3          Y       99     303   31     2       0       0       0       0
# 4          Y       99     306   62     2       0       0       0       0
# ...      ...      ...     ...  ...   ...     ...     ...     ...     ...
# 14011      Y       99  151601   30     2       0       0       0       0
# 14012      Y        1  151634   27     2       1       3       3       1
# 14013      Y       99  151679   26     2       0       0       0       0
# 14014      Y        1  151804   75     2       1       3       3       1
# 14015      Y       99  151811   61     2       0       0       0       0
#
#        turnover_A   turnover_B  age_P  lor_M
# 0      333.561114   264.721010     66      3
# 1      394.735699   284.904978     45     39
# 2      342.180990  1175.589721     42     27
# 3      453.757916   242.341754     31      3
# 4      384.577469   287.008370     62      3
# ...           ...          ...    ...    ...
# 14011  386.434278   284.309508     30      3
# 14012  376.842591   266.993794     27     27
# 14013  434.805703   284.629361     26      3
# 14014  366.273857   270.573265     75     15
# 14015  445.059067   217.425934     61      3
#
# [14016 rows x 13 columns]

# %%
df.shape
# Out:
# (14016, 13)

# %% [markdown]
# The __shape__ method tells us that the dataset contains __14016__ rows, and each row contains __13__ attributes.

# %% [markdown]
# ------------------------------------------------------
# ### 3. Data  Dictionary

# %% [markdown]
# <body>
#     <h3 style="color: #333; font-family: Arial, sans-serif;">Customer Data Attributes</h3>
#     <table style="width: 100%; border-collapse: collapse; margin-top: 20px;">
#         <tr>
#             <th style="border: 1px solid #999; padding: 10px; text-align: left; background-color: #f2f2f2; color: #333;">Attribute</th>
#             <th style="border: 1px solid #999; padding: 10px; text-align: left; background-color: #f2f2f2; color: #333;">Description</th>
#         </tr>
#         <tr style="background-color: #f2f2f2;">
#             <td style="border: 1px solid #999; padding: 10px; text-align: left;">ID</td>
#             <td style="border: 1px solid #999; padding: 10px; text-align: left;">Unique customer identifier</td>
#         </tr>
#         <tr style="background-color: #f2f2f2;">
#             <td style="border: 1px solid #999; padding: 10px; text-align: left;">TARGET</td>
#             <td style="border: 1px solid #999; padding: 10px; text-align: left;">Indicator of customer buying the new product (N = no, Y = yes)</td>
#         </tr>
#         <tr style="background-color: #f2f2f2;">
#             <td style="border: 1px solid #999; padding: 10px; text-align: left;">Loyalty</td>
#             <td style="border: 1px solid #999; padding: 10px; text-align: left;">Customer loyalty level, from low to high (0 to 3), 99 = unclassified</td>
#         </tr>
#         <tr style="background-color: #f2f2f2;">
#             <td style="border: 1px solid #999; padding: 10px; text-align: left;">Age</td>
#             <td style="border: 1px solid #999; padding: 10px; text-align: left;">Customer age in years</td>
#         </tr>
#         <tr style="background-color: #f2f2f2;">
#             <td style="border: 1px solid #999; padding: 10px; text-align: left;">City</td>
#             <td style="border: 1px solid #999; padding: 10px; text-align: left;">Unique code per city (where the customer resides)</td>
#         </tr>
#         <tr style="background-color: #f2f2f2;">
#             <td style="border: 1px solid #999; padding: 10px; text-align: left;">Age_p</td>
#             <td style="border: 1px solid #999; padding: 10px; text-align: left;">Age of customer’s partner in years</td>
#         </tr>
#         <tr style="background-color: #f2f2f2;">
#             <td style="border: 1px solid #999; padding: 10px; text-align: left;">LOR_m</td>
#             <td style="border: 1px solid #999; padding: 10px; text-align: left;">Length of customer’s relationship with company (in months)</td>
#         </tr>
#         <tr style="background-color: #f2f2f2;">
#             <td style="border: 1px solid #999; padding: 10px; text-align: left;">Prod_A</td>
#             <td style="border: 1px solid #999; padding: 10px; text-align: left;">Customer previously bought Product A (0=no, 1=yes)</td>
#         </tr>
#         <tr style="background-color: #f2f2f2;">
#             <td style="border: 1px solid #999; padding: 10px; text-align: left;">Type_A</td>
#             <td style="border: 1px solid #999; padding: 10px; text-align: left;">Type of product A</td>
#         </tr>
#         <tr style="background-color: #f2f2f2;">
#             <td style="border: 1px solid #999; padding: 10px; text-align: left;">Turnover_A</td>
#             <td style="border: 1px solid #999; padding: 10px; text-align: left;">Amount of money customer spent on Product A</td>
#         </tr>
#         <tr style="background-color: #f2f2f2;">
#             <td style="border: 1px solid #999; padding: 10px; text-align: left;">Prod_B</td>
#             <td style="border: 1px solid #999; padding: 10px; text-align: left;">Customer previously bought Product B (0=no, 1=yes)</td>
#         </tr>
#         <tr style="background-color: #f2f2f2;">
#             <td style="border: 1px solid #999; padding: 10px; text-align: left;">Type_B</td>
#             <td style="border: 1px solid #999; padding: 10px; text-align: left;">Type of product B</td>
#         </tr>
#         <tr style="background-color: #f2f2f2;">
#             <td style="border: 1px solid #999; padding: 10px; text-align: left;">Turnover_B</td>
#             <td style="border: 1px solid #999; padding: 10px; text-align: left;">Amount of money customer spent on Product B</td>
#         </tr>
#     </table>
# </body>

# %% [markdown]
# ### Let's study the attributes of the __df__ data frame with the given data dictionary.

# %% [markdown]
# #### 1. __ID: Unique customer identifier__.
# - As the ID should be unique for the every customer then the no.of unique value in ID should be equal to no. of rows in the data frame df

# %%
# finding out unique number of values in the ID variable
df['ID'].nunique()
# Out:
# 11008

# %% [markdown]
# Although we have __14016__ rows, that should contain 14016 unique ID values but on the contrast we got only __11008__ unique ID values

# %%
# Checking if all values in the 'ID' column are unique
all_unique = df['ID'].is_unique

if all_unique:
    print("All values in the 'id' column are unique.")
else:
    # Counting the occurrences of each value in the 'ID' column
    id_counts = df['ID'].value_counts()
    
    # Filtering out the values that are repeated
    repeated_ids = id_counts[id_counts > 1]
    
    print("The following values in the 'ID' column are repeated:")
    for id_value, count in repeated_ids.items():
        print(f"ID: {id_value}, Repeated {count} times.")
# Out:
# The following values in the 'ID' column are repeated:
# ID: 77, Repeated 2 times.
# ID: 103791, Repeated 2 times.
# ID: 103370, Repeated 2 times.
# ID: 103452, Repeated 2 times.
# ID: 103464, Repeated 2 times.
# ID: 103510, Repeated 2 times.
# ID: 103528, Repeated 2 times.
# ID: 103547, Repeated 2 times.
# ID: 103648, Repeated 2 times.
# ID: 103691, Repeated 2 times.
# ID: 103778, Repeated 2 times.
# ID: 103792, Repeated 2 times.
# ID: 103223, Repeated 2 times.
# ID: 103794, Repeated 2 times.
# ID: 103918, Repeated 2 times.
# ID: 103946, Repeated 2 times.
# ID: 103961, Repeated 2 times.
# ID: 104044, Repeated 2 times.
# ID: 104077, Repeated 2 times.
# ID: 104087, Repeated 2 times.
# ID: 104101, Repeated 2 times.
# ID: 104119, Repeated 2 times.
# ID: 103367, Repeated 2 times.
# ID: 103190, Repeated 2 times.
# ID: 77575, Repeated 2 times.
# ID: 102544, Repeated 2 times.
# ID: 102196, Repeated 2 times.
# ID: 102312, Repeated 2 times.
# ID: 102358, Repeated 2 times.
# ID: 102382, Repeated 2 times.
# ID: 102389, Repeated 2 times.
# ID: 102409, Repeated 2 times.
# ID: 102420, Repeated 2 times.
# ID: 102496, Repeated 2 times.
# ID: 102517, Repeated 2 times.
# ID: 102579, Repeated 2 times.
# ID: 103132, Repeated 2 times.
# ID: 102710, Repeated 2 times.
# ID: 102722, Repeated 2 times.
# ID: 102750, Repeated 2 times.
# ID: 102795, Repeated 2 times.
# ID: 102809, Repeated 2 times.
# ID: 102818, Repeated 2 times.
# ID: 102952, Repeated 2 times.
# ID: 103078, Repeated 2 times.
# ID: 103117, Repeated 2 times.
# ID: 104156, Repeated 2 times.
# ID: 104188, Repeated 2 times.
# ID: 104240, Repeated 2 times.
# ID: 106235, Repeated 2 times.
# ID: 105727, Repeated 2 times.
# ID: 105741, Repeated 2 times.
# ID: 105793, Repeated 2 times.
# ID: 105899, Repeated 2 times.
# ID: 105948, Repeated 2 times.
# ID: 105982, Repeated 2 times.
# ID: 106027, Repeated 2 times.
# ID: 106065, Repeated 2 times.
# ID: 106152, Repeated 2 times.
# ID: 106271, Repeated 2 times.
# ID: 104250, Repeated 2 times.
# ID: 106280, Repeated 2 times.
# ID: 106312, Repeated 2 times.
# ID: 106396, Repeated 2 times.
# ID: 106449, Repeated 2 times.
# ID: 106536, Repeated 2 times.
# ID: 106544, Repeated 2 times.
# ID: 106556, Repeated 2 times.
# ID: 106642, Repeated 2 times.
# ID: 106672, Repeated 2 times.
# ID: 105696, Repeated 2 times.
# ID: 105552, Repeated 2 times.
# ID: 105335, Repeated 2 times.
# ID: 105234, Repeated 2 times.
# ID: 104286, Repeated 2 times.
# ID: 104293, Repeated 2 times.
# ID: 104319, Repeated 2 times.
# ID: 104342, Repeated 2 times.
# ID: 104517, Repeated 2 times.
# ID: 104620, Repeated 2 times.
# ID: 104764, Repeated 2 times.
# ID: 104776, Repeated 2 times.
# ID: 104797, Repeated 2 times.
# ID: 104804, Repeated 2 times.
# ID: 104832, Repeated 2 times.
# ID: 104849, Repeated 2 times.
# ID: 104882, Repeated 2 times.
# ID: 104997, Repeated 2 times.
# ID: 105007, Repeated 2 times.
# ID: 105047, Repeated 2 times.
# ID: 105084, Repeated 2 times.
# ID: 105146, Repeated 2 times.
# ID: 105175, Repeated 2 times.
# ID: 102129, Repeated 2 times.
# ID: 102067, Repeated 2 times.
# ID: 101970, Repeated 2 times.
# ID: 98898, Repeated 2 times.
# ID: 98534, Repeated 2 times.
# ID: 98549, Repeated 2 times.
# ID: 98641, Repeated 2 times.
# ID: 98661, Repeated 2 times.
# ID: 98706, Repeated 2 times.
# ID: 98806, Repeated 2 times.
# ID: 98850, Repeated 2 times.
# ID: 98859, Repeated 2 times.
# ID: 98897, Repeated 2 times.
# ID: 98934, Repeated 2 times.
# ID: 99271, Repeated 2 times.
# ID: 99023, Repeated 2 times.
# ID: 99063, Repeated 2 times.
# ID: 99093, Repeated 2 times.
# ID: 99107, Repeated 2 times.
# ID: 99147, Repeated 2 times.
# ID: 99176, Repeated 2 times.
# ID: 99214, Repeated 2 times.
# ID: 99249, Repeated 2 times.
# ID: 99252, Repeated 2 times.
# ID: 98505, Repeated 2 times.
# ID: 98368, Repeated 2 times.
# ID: 98325, Repeated 2 times.
# ID: 98292, Repeated 2 times.
# ID: 97230, Repeated 2 times.
# ID: 97231, Repeated 2 times.
# ID: 97282, Repeated 2 times.
# ID: 97310, Repeated 2 times.
# ID: 97343, Repeated 2 times.
# ID: 97469, Repeated 2 times.
# ID: 97503, Repeated 2 times.
# ID: 97556, Repeated 2 times.
# ID: 97744, Repeated 2 times.
# ID: 97878, Repeated 2 times.
# ID: 98006, Repeated 2 times.
# ID: 98042, Repeated 2 times.
# ID: 98134, Repeated 2 times.
# ID: 98153, Repeated 2 times.
# ID: 98165, Repeated 2 times.
# ID: 98187, Repeated 2 times.
# ID: 98236, Repeated 2 times.
# ID: 98262, Repeated 2 times.
# ID: 98279, Repeated 2 times.
# ID: 99255, Repeated 2 times.
# ID: 99323, Repeated 2 times.
# ID: 101895, Repeated 2 times.
# ID: 101502, Repeated 2 times.
# ID: 101096, Repeated 2 times.
# ID: 101112, Repeated 2 times.
# ID: 101113, Repeated 2 times.
# ID: 101142, Repeated 2 times.
# ID: 101148, Repeated 2 times.
# ID: 101189, Repeated 2 times.
# ID: 101232, Repeated 2 times.
# ID: 101245, Repeated 2 times.
# ID: 101459, Repeated 2 times.
# ID: 101549, Repeated 2 times.
# ID: 99331, Repeated 2 times.
# ID: 101590, Repeated 2 times.
# ID: 101592, Repeated 2 times.
# ID: 101710, Repeated 2 times.
# ID: 101713, Repeated 2 times.
# ID: 101744, Repeated 2 times.
# ID: 101790, Repeated 2 times.
# ID: 101805, Repeated 2 times.
# ID: 101864, Repeated 2 times.
# ID: 101873, Repeated 2 times.
# ID: 101016, Repeated 2 times.
# ID: 101004, Repeated 2 times.
# ID: 100921, Repeated 2 times.
# ID: 100802, Repeated 2 times.
# ID: 99516, Repeated 2 times.
# ID: 99555, Repeated 2 times.
# ID: 99761, Repeated 2 times.
# ID: 99783, Repeated 2 times.
# ID: 99816, Repeated 2 times.
# ID: 99821, Repeated 2 times.
# ID: 99834, Repeated 2 times.
# ID: 99894, Repeated 2 times.
# ID: 99941, Repeated 2 times.
# ID: 100207, Repeated 2 times.
# ID: 100271, Repeated 2 times.
# ID: 100286, Repeated 2 times.
# ID: 100354, Repeated 2 times.
# ID: 100437, Repeated 2 times.
# ID: 100555, Repeated 2 times.
# ID: 100567, Repeated 2 times.
# ID: 100598, Repeated 2 times.
# ID: 100714, Repeated 2 times.
# ID: 100727, Repeated 2 times.
# ID: 106694, Repeated 2 times.
# ID: 106703, Repeated 2 times.
# ID: 106766, Repeated 2 times.
# ID: 113675, Repeated 2 times.
# ID: 113343, Repeated 2 times.
# ID: 113377, Repeated 2 times.
# ID: 113379, Repeated 2 times.
# ID: 113414, Repeated 2 times.
# ID: 113457, Repeated 2 times.
# ID: 113488, Repeated 2 times.
# ID: 113560, Repeated 2 times.
# ID: 113592, Repeated 2 times.
# ID: 113633, Repeated 2 times.
# ID: 113714, Repeated 2 times.
# ID: 114787, Repeated 2 times.
# ID: 113716, Repeated 2 times.
# ID: 113758, Repeated 2 times.
# ID: 114102, Repeated 2 times.
# ID: 114133, Repeated 2 times.
# ID: 114152, Repeated 2 times.
# ID: 114278, Repeated 2 times.
# ID: 114303, Repeated 2 times.
# ID: 114322, Repeated 2 times.
# ID: 114673, Repeated 2 times.
# ID: 113296, Repeated 2 times.
# ID: 113267, Repeated 2 times.
# ID: 113180, Repeated 2 times.
# ID: 113168, Repeated 2 times.
# ID: 112008, Repeated 2 times.
# ID: 112117, Repeated 2 times.
# ID: 112128, Repeated 2 times.
# ID: 112130, Repeated 2 times.
# ID: 112185, Repeated 2 times.
# ID: 112210, Repeated 2 times.
# ID: 112256, Repeated 2 times.
# ID: 112288, Repeated 2 times.
# ID: 112309, Repeated 2 times.
# ID: 112326, Repeated 2 times.
# ID: 112339, Repeated 2 times.
# ID: 112509, Repeated 2 times.
# ID: 112717, Repeated 2 times.
# ID: 112725, Repeated 2 times.
# ID: 112786, Repeated 2 times.
# ID: 112789, Repeated 2 times.
# ID: 113007, Repeated 2 times.
# ID: 113050, Repeated 2 times.
# ID: 113118, Repeated 2 times.
# ID: 114720, Repeated 2 times.
# ID: 114883, Repeated 2 times.
# ID: 111726, Repeated 2 times.
# ID: 116319, Repeated 2 times.
# ID: 115894, Repeated 2 times.
# ID: 115987, Repeated 2 times.
# ID: 116115, Repeated 2 times.
# ID: 116116, Repeated 2 times.
# ID: 116140, Repeated 2 times.
# ID: 116162, Repeated 2 times.
# ID: 116188, Repeated 2 times.
# ID: 116199, Repeated 2 times.
# ID: 116238, Repeated 2 times.
# ID: 116358, Repeated 2 times.
# ID: 114893, Repeated 2 times.
# ID: 116577, Repeated 2 times.
# ID: 116587, Repeated 2 times.
# ID: 116685, Repeated 2 times.
# ID: 116738, Repeated 2 times.
# ID: 116778, Repeated 2 times.
# ID: 116793, Repeated 2 times.
# ID: 116836, Repeated 2 times.
# ID: 116838, Repeated 2 times.
# ID: 116875, Repeated 2 times.
# ID: 115828, Repeated 2 times.
# ID: 115817, Repeated 2 times.
# ID: 115784, Repeated 2 times.
# ID: 115654, Repeated 2 times.
# ID: 114948, Repeated 2 times.
# ID: 114961, Repeated 2 times.
# ID: 115024, Repeated 2 times.
# ID: 115038, Repeated 2 times.
# ID: 115085, Repeated 2 times.
# ID: 115144, Repeated 2 times.
# ID: 115275, Repeated 2 times.
# ID: 115291, Repeated 2 times.
# ID: 115317, Repeated 2 times.
# ID: 115369, Repeated 2 times.
# ID: 115378, Repeated 2 times.
# ID: 115402, Repeated 2 times.
# ID: 115444, Repeated 2 times.
# ID: 115453, Repeated 2 times.
# ID: 115481, Repeated 2 times.
# ID: 115513, Repeated 2 times.
# ID: 115569, Repeated 2 times.
# ID: 115586, Repeated 2 times.
# ID: 115643, Repeated 2 times.
# ID: 111750, Repeated 2 times.
# ID: 111553, Repeated 2 times.
# ID: 106779, Repeated 2 times.
# ID: 108435, Repeated 2 times.
# ID: 108075, Repeated 2 times.
# ID: 108093, Repeated 2 times.
# ID: 108103, Repeated 2 times.
# ID: 108143, Repeated 2 times.
# ID: 108145, Repeated 2 times.
# ID: 108239, Repeated 2 times.
# ID: 108244, Repeated 2 times.
# ID: 108335, Repeated 2 times.
# ID: 108422, Repeated 2 times.
# ID: 108460, Repeated 2 times.
# ID: 109100, Repeated 2 times.
# ID: 108461, Repeated 2 times.
# ID: 108696, Repeated 2 times.
# ID: 108778, Repeated 2 times.
# ID: 108807, Repeated 2 times.
# ID: 108829, Repeated 2 times.
# ID: 108867, Repeated 2 times.
# ID: 109026, Repeated 2 times.
# ID: 109031, Repeated 2 times.
# ID: 109090, Repeated 2 times.
# ID: 108034, Repeated 2 times.
# ID: 108026, Repeated 2 times.
# ID: 108015, Repeated 2 times.
# ID: 107936, Repeated 2 times.
# ID: 106807, Repeated 2 times.
# ID: 106872, Repeated 2 times.
# ID: 106921, Repeated 2 times.
# ID: 106944, Repeated 2 times.
# ID: 106974, Repeated 2 times.
# ID: 106990, Repeated 2 times.
# ID: 107064, Repeated 2 times.
# ID: 107154, Repeated 2 times.
# ID: 107247, Repeated 2 times.
# ID: 107301, Repeated 2 times.
# ID: 107305, Repeated 2 times.
# ID: 107322, Repeated 2 times.
# ID: 107335, Repeated 2 times.
# ID: 107417, Repeated 2 times.
# ID: 107491, Repeated 2 times.
# ID: 107595, Repeated 2 times.
# ID: 107739, Repeated 2 times.
# ID: 107755, Repeated 2 times.
# ID: 107890, Repeated 2 times.
# ID: 109091, Repeated 2 times.
# ID: 109108, Repeated 2 times.
# ID: 111199, Repeated 2 times.
# ID: 110858, Repeated 2 times.
# ID: 110170, Repeated 2 times.
# ID: 110187, Repeated 2 times.
# ID: 110220, Repeated 2 times.
# ID: 110371, Repeated 2 times.
# ID: 110463, Repeated 2 times.
# ID: 110566, Repeated 2 times.
# ID: 110578, Repeated 2 times.
# ID: 110623, Repeated 2 times.
# ID: 110734, Repeated 2 times.
# ID: 110861, Repeated 2 times.
# ID: 109114, Repeated 2 times.
# ID: 110898, Repeated 2 times.
# ID: 111013, Repeated 2 times.
# ID: 111017, Repeated 2 times.
# ID: 111026, Repeated 2 times.
# ID: 111027, Repeated 2 times.
# ID: 111043, Repeated 2 times.
# ID: 111131, Repeated 2 times.
# ID: 111140, Repeated 2 times.
# ID: 111156, Repeated 2 times.
# ID: 110099, Repeated 2 times.
# ID: 110089, Repeated 2 times.
# ID: 110071, Repeated 2 times.
# ID: 110037, Repeated 2 times.
# ID: 109121, Repeated 2 times.
# ID: 109187, Repeated 2 times.
# ID: 109228, Repeated 2 times.
# ID: 109236, Repeated 2 times.
# ID: 109305, Repeated 2 times.
# ID: 109352, Repeated 2 times.
# ID: 109416, Repeated 2 times.
# ID: 109451, Repeated 2 times.
# ID: 109528, Repeated 2 times.
# ID: 109602, Repeated 2 times.
# ID: 109755, Repeated 2 times.
# ID: 109775, Repeated 2 times.
# ID: 109786, Repeated 2 times.
# ID: 109873, Repeated 2 times.
# ID: 109875, Repeated 2 times.
# ID: 109883, Repeated 2 times.
# ID: 110008, Repeated 2 times.
# ID: 110018, Repeated 2 times.
# ID: 110031, Repeated 2 times.
# ID: 97220, Repeated 2 times.
# ID: 97137, Repeated 2 times.
# ID: 97061, Repeated 2 times.
# ID: 84620, Repeated 2 times.
# ID: 84192, Repeated 2 times.
# ID: 84217, Repeated 2 times.
# ID: 84250, Repeated 2 times.
# ID: 84274, Repeated 2 times.
# ID: 84297, Repeated 2 times.
# ID: 84327, Repeated 2 times.
# ID: 84331, Repeated 2 times.
# ID: 84390, Repeated 2 times.
# ID: 84415, Repeated 2 times.
# ID: 84636, Repeated 2 times.
# ID: 85379, Repeated 2 times.
# ID: 84700, Repeated 2 times.
# ID: 84707, Repeated 2 times.
# ID: 84736, Repeated 2 times.
# ID: 84868, Repeated 2 times.
# ID: 84944, Repeated 2 times.
# ID: 85118, Repeated 2 times.
# ID: 85142, Repeated 2 times.
# ID: 85176, Repeated 2 times.
# ID: 85213, Repeated 2 times.
# ID: 84027, Repeated 2 times.
# ID: 84017, Repeated 2 times.
# ID: 83894, Repeated 2 times.
# ID: 83855, Repeated 2 times.
# ID: 82861, Repeated 2 times.
# ID: 82932, Repeated 2 times.
# ID: 82952, Repeated 2 times.
# ID: 83046, Repeated 2 times.
# ID: 83109, Repeated 2 times.
# ID: 83155, Repeated 2 times.
# ID: 83320, Repeated 2 times.
# ID: 83396, Repeated 2 times.
# ID: 83427, Repeated 2 times.
# ID: 83496, Repeated 2 times.
# ID: 83512, Repeated 2 times.
# ID: 83560, Repeated 2 times.
# ID: 83585, Repeated 2 times.
# ID: 83609, Repeated 2 times.
# ID: 83661, Repeated 2 times.
# ID: 83717, Repeated 2 times.
# ID: 83751, Repeated 2 times.
# ID: 83799, Repeated 2 times.
# ID: 83843, Repeated 2 times.
# ID: 85312, Repeated 2 times.
# ID: 85426, Repeated 2 times.
# ID: 82648, Repeated 2 times.
# ID: 86953, Repeated 2 times.
# ID: 86418, Repeated 2 times.
# ID: 86460, Repeated 2 times.
# ID: 86479, Repeated 2 times.
# ID: 86499, Repeated 2 times.
# ID: 86506, Repeated 2 times.
# ID: 86654, Repeated 2 times.
# ID: 86665, Repeated 2 times.
# ID: 86683, Repeated 2 times.
# ID: 86865, Repeated 2 times.
# ID: 87004, Repeated 2 times.
# ID: 85432, Repeated 2 times.
# ID: 87047, Repeated 2 times.
# ID: 87107, Repeated 2 times.
# ID: 87110, Repeated 2 times.
# ID: 87297, Repeated 2 times.
# ID: 87300, Repeated 2 times.
# ID: 87358, Repeated 2 times.
# ID: 87394, Repeated 2 times.
# ID: 87396, Repeated 2 times.
# ID: 87413, Repeated 2 times.
# ID: 86351, Repeated 2 times.
# ID: 86332, Repeated 2 times.
# ID: 86289, Repeated 2 times.
# ID: 86103, Repeated 2 times.
# ID: 85459, Repeated 2 times.
# ID: 85467, Repeated 2 times.
# ID: 85481, Repeated 2 times.
# ID: 85545, Repeated 2 times.
# ID: 85650, Repeated 2 times.
# ID: 85651, Repeated 2 times.
# ID: 85705, Repeated 2 times.
# ID: 85785, Repeated 2 times.
# ID: 85816, Repeated 2 times.
# ID: 85862, Repeated 2 times.
# ID: 85889, Repeated 2 times.
# ID: 85897, Repeated 2 times.
# ID: 85914, Repeated 2 times.
# ID: 85925, Repeated 2 times.
# ID: 85937, Repeated 2 times.
# ID: 86027, Repeated 2 times.
# ID: 86046, Repeated 2 times.
# ID: 86087, Repeated 2 times.
# ID: 86089, Repeated 2 times.
# ID: 82833, Repeated 2 times.
# ID: 82610, Repeated 2 times.
# ID: 87616, Repeated 2 times.
# ID: 79284, Repeated 2 times.
# ID: 78810, Repeated 2 times.
# ID: 78850, Repeated 2 times.
# ID: 78944, Repeated 2 times.
# ID: 78977, Repeated 2 times.
# ID: 79142, Repeated 2 times.
# ID: 79206, Repeated 2 times.
# ID: 79209, Repeated 2 times.
# ID: 79254, Repeated 2 times.
# ID: 79267, Repeated 2 times.
# ID: 79314, Repeated 2 times.
# ID: 79928, Repeated 2 times.
# ID: 79454, Repeated 2 times.
# ID: 79486, Repeated 2 times.
# ID: 79595, Repeated 2 times.
# ID: 79613, Repeated 2 times.
# ID: 79640, Repeated 2 times.
# ID: 79771, Repeated 2 times.
# ID: 79801, Repeated 2 times.
# ID: 79901, Repeated 2 times.
# ID: 79910, Repeated 2 times.
# ID: 78771, Repeated 2 times.
# ID: 78754, Repeated 2 times.
# ID: 78752, Repeated 2 times.
# ID: 78713, Repeated 2 times.
# ID: 77706, Repeated 2 times.
# ID: 77867, Repeated 2 times.
# ID: 77876, Repeated 2 times.
# ID: 77904, Repeated 2 times.
# ID: 77939, Repeated 2 times.
# ID: 77946, Repeated 2 times.
# ID: 78141, Repeated 2 times.
# ID: 78169, Repeated 2 times.
# ID: 78203, Repeated 2 times.
# ID: 78228, Repeated 2 times.
# ID: 78242, Repeated 2 times.
# ID: 78245, Repeated 2 times.
# ID: 78288, Repeated 2 times.
# ID: 78412, Repeated 2 times.
# ID: 78444, Repeated 2 times.
# ID: 78449, Repeated 2 times.
# ID: 78602, Repeated 2 times.
# ID: 78613, Repeated 2 times.
# ID: 78615, Repeated 2 times.
# ID: 79918, Repeated 2 times.
# ID: 80055, Repeated 2 times.
# ID: 82595, Repeated 2 times.
# ID: 81990, Repeated 2 times.
# ID: 81158, Repeated 2 times.
# ID: 81251, Repeated 2 times.
# ID: 81363, Repeated 2 times.
# ID: 81510, Repeated 2 times.
# ID: 81611, Repeated 2 times.
# ID: 81652, Repeated 2 times.
# ID: 81756, Repeated 2 times.
# ID: 81784, Repeated 2 times.
# ID: 81875, Repeated 2 times.
# ID: 82161, Repeated 2 times.
# ID: 80120, Repeated 2 times.
# ID: 82218, Repeated 2 times.
# ID: 82247, Repeated 2 times.
# ID: 82299, Repeated 2 times.
# ID: 82309, Repeated 2 times.
# ID: 82361, Repeated 2 times.
# ID: 82415, Repeated 2 times.
# ID: 82420, Repeated 2 times.
# ID: 82519, Repeated 2 times.
# ID: 82540, Repeated 2 times.
# ID: 81139, Repeated 2 times.
# ID: 81134, Repeated 2 times.
# ID: 81100, Repeated 2 times.
# ID: 81039, Repeated 2 times.
# ID: 80185, Repeated 2 times.
# ID: 80188, Repeated 2 times.
# ID: 80224, Repeated 2 times.
# ID: 80301, Repeated 2 times.
# ID: 80302, Repeated 2 times.
# ID: 80304, Repeated 2 times.
# ID: 80328, Repeated 2 times.
# ID: 80343, Repeated 2 times.
# ID: 80420, Repeated 2 times.
# ID: 80590, Repeated 2 times.
# ID: 80705, Repeated 2 times.
# ID: 80727, Repeated 2 times.
# ID: 80779, Repeated 2 times.
# ID: 80827, Repeated 2 times.
# ID: 80843, Repeated 2 times.
# ID: 80849, Repeated 2 times.
# ID: 80905, Repeated 2 times.
# ID: 80948, Repeated 2 times.
# ID: 80983, Repeated 2 times.
# ID: 87479, Repeated 2 times.
# ID: 87633, Repeated 2 times.
# ID: 96972, Repeated 2 times.
# ID: 94053, Repeated 2 times.
# ID: 93532, Repeated 2 times.
# ID: 93761, Repeated 2 times.
# ID: 93763, Repeated 2 times.
# ID: 93784, Repeated 2 times.
# ID: 93813, Repeated 2 times.
# ID: 93845, Repeated 2 times.
# ID: 93885, Repeated 2 times.
# ID: 93951, Repeated 2 times.
# ID: 94026, Repeated 2 times.
# ID: 94065, Repeated 2 times.
# ID: 94856, Repeated 2 times.
# ID: 94119, Repeated 2 times.
# ID: 94131, Repeated 2 times.
# ID: 94278, Repeated 2 times.
# ID: 94445, Repeated 2 times.
# ID: 94508, Repeated 2 times.
# ID: 94525, Repeated 2 times.
# ID: 94533, Repeated 2 times.
# ID: 94544, Repeated 2 times.
# ID: 94633, Repeated 2 times.
# ID: 93507, Repeated 2 times.
# ID: 93435, Repeated 2 times.
# ID: 93399, Repeated 2 times.
# ID: 93385, Repeated 2 times.
# ID: 92664, Repeated 2 times.
# ID: 92680, Repeated 2 times.
# ID: 92732, Repeated 2 times.
# ID: 92739, Repeated 2 times.
# ID: 92752, Repeated 2 times.
# ID: 92781, Repeated 2 times.
# ID: 92821, Repeated 2 times.
# ID: 92837, Repeated 2 times.
# ID: 92915, Repeated 2 times.
# ID: 92917, Repeated 2 times.
# ID: 92956, Repeated 2 times.
# ID: 92986, Repeated 2 times.
# ID: 93044, Repeated 2 times.
# ID: 93053, Repeated 2 times.
# ID: 93267, Repeated 2 times.
# ID: 93311, Repeated 2 times.
# ID: 93314, Repeated 2 times.
# ID: 93335, Repeated 2 times.
# ID: 93340, Repeated 2 times.
# ID: 94730, Repeated 2 times.
# ID: 94892, Repeated 2 times.
# ID: 92647, Repeated 2 times.
# ID: 96363, Repeated 2 times.
# ID: 95800, Repeated 2 times.
# ID: 95941, Repeated 2 times.
# ID: 95964, Repeated 2 times.
# ID: 96003, Repeated 2 times.
# ID: 96023, Repeated 2 times.
# ID: 96153, Repeated 2 times.
# ID: 96159, Repeated 2 times.
# ID: 96275, Repeated 2 times.
# ID: 96343, Repeated 2 times.
# ID: 96370, Repeated 2 times.
# ID: 94956, Repeated 2 times.
# ID: 96475, Repeated 2 times.
# ID: 96513, Repeated 2 times.
# ID: 96684, Repeated 2 times.
# ID: 96767, Repeated 2 times.
# ID: 96772, Repeated 2 times.
# ID: 96794, Repeated 2 times.
# ID: 96859, Repeated 2 times.
# ID: 96896, Repeated 2 times.
# ID: 96947, Repeated 2 times.
# ID: 95730, Repeated 2 times.
# ID: 95727, Repeated 2 times.
# ID: 95674, Repeated 2 times.
# ID: 95636, Repeated 2 times.
# ID: 95042, Repeated 2 times.
# ID: 95165, Repeated 2 times.
# ID: 95167, Repeated 2 times.
# ID: 95169, Repeated 2 times.
# ID: 95194, Repeated 2 times.
# ID: 95231, Repeated 2 times.
# ID: 95241, Repeated 2 times.
# ID: 95261, Repeated 2 times.
# ID: 95286, Repeated 2 times.
# ID: 95301, Repeated 2 times.
# ID: 95461, Repeated 2 times.
# ID: 95503, Repeated 2 times.
# ID: 95529, Repeated 2 times.
# ID: 95577, Repeated 2 times.
# ID: 95588, Repeated 2 times.
# ID: 95595, Repeated 2 times.
# ID: 95607, Repeated 2 times.
# ID: 95611, Repeated 2 times.
# ID: 95632, Repeated 2 times.
# ID: 92651, Repeated 2 times.
# ID: 92509, Repeated 2 times.
# ID: 87654, Repeated 2 times.
# ID: 89586, Repeated 2 times.
# ID: 89180, Repeated 2 times.
# ID: 89198, Repeated 2 times.
# ID: 89282, Repeated 2 times.
# ID: 89408, Repeated 2 times.
# ID: 89442, Repeated 2 times.
# ID: 89446, Repeated 2 times.
# ID: 89472, Repeated 2 times.
# ID: 89513, Repeated 2 times.
# ID: 89538, Repeated 2 times.
# ID: 89740, Repeated 2 times.
# ID: 90075, Repeated 2 times.
# ID: 89788, Repeated 2 times.
# ID: 89800, Repeated 2 times.
# ID: 89808, Repeated 2 times.
# ID: 89835, Repeated 2 times.
# ID: 89865, Repeated 2 times.
# ID: 89866, Repeated 2 times.
# ID: 89877, Repeated 2 times.
# ID: 89956, Repeated 2 times.
# ID: 89964, Repeated 2 times.
# ID: 89156, Repeated 2 times.
# ID: 89103, Repeated 2 times.
# ID: 89092, Repeated 2 times.
# ID: 88791, Repeated 2 times.
# ID: 87827, Repeated 2 times.
# ID: 87858, Repeated 2 times.
# ID: 87935, Repeated 2 times.
# ID: 87966, Repeated 2 times.
# ID: 88021, Repeated 2 times.
# ID: 88155, Repeated 2 times.
# ID: 88178, Repeated 2 times.
# ID: 88208, Repeated 2 times.
# ID: 88218, Repeated 2 times.
# ID: 88220, Repeated 2 times.
# ID: 88236, Repeated 2 times.
# ID: 88320, Repeated 2 times.
# ID: 88537, Repeated 2 times.
# ID: 88552, Repeated 2 times.
# ID: 88583, Repeated 2 times.
# ID: 88610, Repeated 2 times.
# ID: 88700, Repeated 2 times.
# ID: 88787, Repeated 2 times.
# ID: 88790, Repeated 2 times.
# ID: 89992, Repeated 2 times.
# ID: 90100, Repeated 2 times.
# ID: 92482, Repeated 2 times.
# ID: 91938, Repeated 2 times.
# ID: 91375, Repeated 2 times.
# ID: 91496, Repeated 2 times.
# ID: 91573, Repeated 2 times.
# ID: 91592, Repeated 2 times.
# ID: 91698, Repeated 2 times.
# ID: 91702, Repeated 2 times.
# ID: 91708, Repeated 2 times.
# ID: 91720, Repeated 2 times.
# ID: 91799, Repeated 2 times.
# ID: 92011, Repeated 2 times.
# ID: 90209, Repeated 2 times.
# ID: 92144, Repeated 2 times.
# ID: 92147, Repeated 2 times.
# ID: 92238, Repeated 2 times.
# ID: 92255, Repeated 2 times.
# ID: 92301, Repeated 2 times.
# ID: 92325, Repeated 2 times.
# ID: 92332, Repeated 2 times.
# ID: 92455, Repeated 2 times.
# ID: 92470, Repeated 2 times.
# ID: 91356, Repeated 2 times.
# ID: 91348, Repeated 2 times.
# ID: 91204, Repeated 2 times.
# ID: 91185, Repeated 2 times.
# ID: 90210, Repeated 2 times.
# ID: 90267, Repeated 2 times.
# ID: 90305, Repeated 2 times.
# ID: 90307, Repeated 2 times.
# ID: 90324, Repeated 2 times.
# ID: 90402, Repeated 2 times.
# ID: 90492, Repeated 2 times.
# ID: 90600, Repeated 2 times.
# ID: 90604, Repeated 2 times.
# ID: 90646, Repeated 2 times.
# ID: 90706, Repeated 2 times.
# ID: 90754, Repeated 2 times.
# ID: 90758, Repeated 2 times.
# ID: 90780, Repeated 2 times.
# ID: 90869, Repeated 2 times.
# ID: 90892, Repeated 2 times.
# ID: 91009, Repeated 2 times.
# ID: 91033, Repeated 2 times.
# ID: 91117, Repeated 2 times.
# ID: 116897, Repeated 2 times.
# ID: 117031, Repeated 2 times.
# ID: 117042, Repeated 2 times.
# ID: 140109, Repeated 2 times.
# ID: 139877, Repeated 2 times.
# ID: 139887, Repeated 2 times.
# ID: 139963, Repeated 2 times.
# ID: 139990, Repeated 2 times.
# ID: 139995, Repeated 2 times.
# ID: 139998, Repeated 2 times.
# ID: 140012, Repeated 2 times.
# ID: 140016, Repeated 2 times.
# ID: 140092, Repeated 2 times.
# ID: 140112, Repeated 2 times.
# ID: 140698, Repeated 2 times.
# ID: 140151, Repeated 2 times.
# ID: 140344, Repeated 2 times.
# ID: 140421, Repeated 2 times.
# ID: 140431, Repeated 2 times.
# ID: 140465, Repeated 2 times.
# ID: 140511, Repeated 2 times.
# ID: 140657, Repeated 2 times.
# ID: 140664, Repeated 2 times.
# ID: 140686, Repeated 2 times.
# ID: 139860, Repeated 2 times.
# ID: 139753, Repeated 2 times.
# ID: 139687, Repeated 2 times.
# ID: 139633, Repeated 2 times.
# ID: 138706, Repeated 2 times.
# ID: 138784, Repeated 2 times.
# ID: 138845, Repeated 2 times.
# ID: 138846, Repeated 2 times.
# ID: 138907, Repeated 2 times.
# ID: 138911, Repeated 2 times.
# ID: 138943, Repeated 2 times.
# ID: 138949, Repeated 2 times.
# ID: 138953, Repeated 2 times.
# ID: 138967, Repeated 2 times.
# ID: 139112, Repeated 2 times.
# ID: 139149, Repeated 2 times.
# ID: 139202, Repeated 2 times.
# ID: 139291, Repeated 2 times.
# ID: 139308, Repeated 2 times.
# ID: 139363, Repeated 2 times.
# ID: 139397, Repeated 2 times.
# ID: 139458, Repeated 2 times.
# ID: 139475, Repeated 2 times.
# ID: 140693, Repeated 2 times.
# ID: 140749, Repeated 2 times.
# ID: 138669, Repeated 2 times.
# ID: 142585, Repeated 2 times.
# ID: 142120, Repeated 2 times.
# ID: 142137, Repeated 2 times.
# ID: 142164, Repeated 2 times.
# ID: 142268, Repeated 2 times.
# ID: 142294, Repeated 2 times.
# ID: 142354, Repeated 2 times.
# ID: 142392, Repeated 2 times.
# ID: 142500, Repeated 2 times.
# ID: 142525, Repeated 2 times.
# ID: 142617, Repeated 2 times.
# ID: 140882, Repeated 2 times.
# ID: 142622, Repeated 2 times.
# ID: 142686, Repeated 2 times.
# ID: 142793, Repeated 2 times.
# ID: 142804, Repeated 2 times.
# ID: 142844, Repeated 2 times.
# ID: 142882, Repeated 2 times.
# ID: 142988, Repeated 2 times.
# ID: 143035, Repeated 2 times.
# ID: 143161, Repeated 2 times.
# ID: 142081, Repeated 2 times.
# ID: 142015, Repeated 2 times.
# ID: 141973, Repeated 2 times.
# ID: 141953, Repeated 2 times.
# ID: 140950, Repeated 2 times.
# ID: 140963, Repeated 2 times.
# ID: 140971, Repeated 2 times.
# ID: 140979, Repeated 2 times.
# ID: 141099, Repeated 2 times.
# ID: 141176, Repeated 2 times.
# ID: 141195, Repeated 2 times.
# ID: 141243, Repeated 2 times.
# ID: 141268, Repeated 2 times.
# ID: 141322, Repeated 2 times.
# ID: 141327, Repeated 2 times.
# ID: 141400, Repeated 2 times.
# ID: 141417, Repeated 2 times.
# ID: 141520, Repeated 2 times.
# ID: 141568, Repeated 2 times.
# ID: 141605, Repeated 2 times.
# ID: 141643, Repeated 2 times.
# ID: 141900, Repeated 2 times.
# ID: 141951, Repeated 2 times.
# ID: 138695, Repeated 2 times.
# ID: 138639, Repeated 2 times.
# ID: 143236, Repeated 2 times.
# ID: 135884, Repeated 2 times.
# ID: 135459, Repeated 2 times.
# ID: 135518, Repeated 2 times.
# ID: 135599, Repeated 2 times.
# ID: 135620, Repeated 2 times.
# ID: 135630, Repeated 2 times.
# ID: 135667, Repeated 2 times.
# ID: 135743, Repeated 2 times.
# ID: 135847, Repeated 2 times.
# ID: 135867, Repeated 2 times.
# ID: 135993, Repeated 2 times.
# ID: 136462, Repeated 2 times.
# ID: 136002, Repeated 2 times.
# ID: 136035, Repeated 2 times.
# ID: 136136, Repeated 2 times.
# ID: 136139, Repeated 2 times.
# ID: 136257, Repeated 2 times.
# ID: 136260, Repeated 2 times.
# ID: 136339, Repeated 2 times.
# ID: 136372, Repeated 2 times.
# ID: 136392, Repeated 2 times.
# ID: 135456, Repeated 2 times.
# ID: 135452, Repeated 2 times.
# ID: 135435, Repeated 2 times.
# ID: 135422, Repeated 2 times.
# ID: 134393, Repeated 2 times.
# ID: 134420, Repeated 2 times.
# ID: 134426, Repeated 2 times.
# ID: 134472, Repeated 2 times.
# ID: 134516, Repeated 2 times.
# ID: 134557, Repeated 2 times.
# ID: 134684, Repeated 2 times.
# ID: 134693, Repeated 2 times.
# ID: 134698, Repeated 2 times.
# ID: 134736, Repeated 2 times.
# ID: 134747, Repeated 2 times.
# ID: 134804, Repeated 2 times.
# ID: 134816, Repeated 2 times.
# ID: 135004, Repeated 2 times.
# ID: 135066, Repeated 2 times.
# ID: 135096, Repeated 2 times.
# ID: 135109, Repeated 2 times.
# ID: 135134, Repeated 2 times.
# ID: 135217, Repeated 2 times.
# ID: 136447, Repeated 2 times.
# ID: 136504, Repeated 2 times.
# ID: 138623, Repeated 2 times.
# ID: 138004, Repeated 2 times.
# ID: 137541, Repeated 2 times.
# ID: 137608, Repeated 2 times.
# ID: 137682, Repeated 2 times.
# ID: 137823, Repeated 2 times.
# ID: 137874, Repeated 2 times.
# ID: 137914, Repeated 2 times.
# ID: 137933, Repeated 2 times.
# ID: 137973, Repeated 2 times.
# ID: 137982, Repeated 2 times.
# ID: 138041, Repeated 2 times.
# ID: 136523, Repeated 2 times.
# ID: 138052, Repeated 2 times.
# ID: 138063, Repeated 2 times.
# ID: 138242, Repeated 2 times.
# ID: 138270, Repeated 2 times.
# ID: 138311, Repeated 2 times.
# ID: 138463, Repeated 2 times.
# ID: 138562, Repeated 2 times.
# ID: 138576, Repeated 2 times.
# ID: 138601, Repeated 2 times.
# ID: 137515, Repeated 2 times.
# ID: 137479, Repeated 2 times.
# ID: 137477, Repeated 2 times.
# ID: 137467, Repeated 2 times.
# ID: 136530, Repeated 2 times.
# ID: 136532, Repeated 2 times.
# ID: 136627, Repeated 2 times.
# ID: 136634, Repeated 2 times.
# ID: 136648, Repeated 2 times.
# ID: 136711, Repeated 2 times.
# ID: 136789, Repeated 2 times.
# ID: 136818, Repeated 2 times.
# ID: 136844, Repeated 2 times.
# ID: 136926, Repeated 2 times.
# ID: 136953, Repeated 2 times.
# ID: 137039, Repeated 2 times.
# ID: 137070, Repeated 2 times.
# ID: 137090, Repeated 2 times.
# ID: 137185, Repeated 2 times.
# ID: 137228, Repeated 2 times.
# ID: 137259, Repeated 2 times.
# ID: 137399, Repeated 2 times.
# ID: 137425, Repeated 2 times.
# ID: 143186, Repeated 2 times.
# ID: 143246, Repeated 2 times.
# ID: 134369, Repeated 2 times.
# ID: 149058, Repeated 2 times.
# ID: 148646, Repeated 2 times.
# ID: 148663, Repeated 2 times.
# ID: 148761, Repeated 2 times.
# ID: 148816, Repeated 2 times.
# ID: 148870, Repeated 2 times.
# ID: 148898, Repeated 2 times.
# ID: 148909, Repeated 2 times.
# ID: 148945, Repeated 2 times.
# ID: 149054, Repeated 2 times.
# ID: 149098, Repeated 2 times.
# ID: 149709, Repeated 2 times.
# ID: 149257, Repeated 2 times.
# ID: 149270, Repeated 2 times.
# ID: 149284, Repeated 2 times.
# ID: 149285, Repeated 2 times.
# ID: 149288, Repeated 2 times.
# ID: 149333, Repeated 2 times.
# ID: 149566, Repeated 2 times.
# ID: 149620, Repeated 2 times.
# ID: 149678, Repeated 2 times.
# ID: 148614, Repeated 2 times.
# ID: 148559, Repeated 2 times.
# ID: 148539, Repeated 2 times.
# ID: 148492, Repeated 2 times.
# ID: 147678, Repeated 2 times.
# ID: 147716, Repeated 2 times.
# ID: 147739, Repeated 2 times.
# ID: 147837, Repeated 2 times.
# ID: 147849, Repeated 2 times.
# ID: 147870, Repeated 2 times.
# ID: 147901, Repeated 2 times.
# ID: 148046, Repeated 2 times.
# ID: 148066, Repeated 2 times.
# ID: 148088, Repeated 2 times.
# ID: 148097, Repeated 2 times.
# ID: 148104, Repeated 2 times.
# ID: 148108, Repeated 2 times.
# ID: 148148, Repeated 2 times.
# ID: 148186, Repeated 2 times.
# ID: 148203, Repeated 2 times.
# ID: 148318, Repeated 2 times.
# ID: 148319, Repeated 2 times.
# ID: 148414, Repeated 2 times.
# ID: 149684, Repeated 2 times.
# ID: 149764, Repeated 2 times.
# ID: 147597, Repeated 2 times.
# ID: 151440, Repeated 2 times.
# ID: 151160, Repeated 2 times.
# ID: 151166, Repeated 2 times.
# ID: 151172, Repeated 2 times.
# ID: 151177, Repeated 2 times.
# ID: 151317, Repeated 2 times.
# ID: 151323, Repeated 2 times.
# ID: 151331, Repeated 2 times.
# ID: 151433, Repeated 2 times.
# ID: 151439, Repeated 2 times.
# ID: 151479, Repeated 2 times.
# ID: 150040, Repeated 2 times.
# ID: 151491, Repeated 2 times.
# ID: 151493, Repeated 2 times.
# ID: 151549, Repeated 2 times.
# ID: 151601, Repeated 2 times.
# ID: 151634, Repeated 2 times.
# ID: 151679, Repeated 2 times.
# ID: 151804, Repeated 2 times.
# ID: 151811, Repeated 2 times.
# ID: 159, Repeated 2 times.
# ID: 151043, Repeated 2 times.
# ID: 150949, Repeated 2 times.
# ID: 150936, Repeated 2 times.
# ID: 150892, Repeated 2 times.
# ID: 150080, Repeated 2 times.
# ID: 150131, Repeated 2 times.
# ID: 150161, Repeated 2 times.
# ID: 150175, Repeated 2 times.
# ID: 150273, Repeated 2 times.
# ID: 150310, Repeated 2 times.
# ID: 150375, Repeated 2 times.
# ID: 150474, Repeated 2 times.
# ID: 150490, Repeated 2 times.
# ID: 150506, Repeated 2 times.
# ID: 150547, Repeated 2 times.
# ID: 150564, Repeated 2 times.
# ID: 150758, Repeated 2 times.
# ID: 150762, Repeated 2 times.
# ID: 150808, Repeated 2 times.
# ID: 150811, Repeated 2 times.
# ID: 150823, Repeated 2 times.
# ID: 150857, Repeated 2 times.
# ID: 150876, Repeated 2 times.
# ID: 147624, Repeated 2 times.
# ID: 147570, Repeated 2 times.
# ID: 143303, Repeated 2 times.
# ID: 144960, Repeated 2 times.
# ID: 144526, Repeated 2 times.
# ID: 144529, Repeated 2 times.
# ID: 144635, Repeated 2 times.
# ID: 144648, Repeated 2 times.
# ID: 144671, Repeated 2 times.
# ID: 144817, Repeated 2 times.
# ID: 144893, Repeated 2 times.
# ID: 144899, Repeated 2 times.
# ID: 144923, Repeated 2 times.
# ID: 145167, Repeated 2 times.
# ID: 145665, Repeated 2 times.
# ID: 145185, Repeated 2 times.
# ID: 145187, Repeated 2 times.
# ID: 145438, Repeated 2 times.
# ID: 145472, Repeated 2 times.
# ID: 145478, Repeated 2 times.
# ID: 145484, Repeated 2 times.
# ID: 145521, Repeated 2 times.
# ID: 145566, Repeated 2 times.
# ID: 145568, Repeated 2 times.
# ID: 144501, Repeated 2 times.
# ID: 144475, Repeated 2 times.
# ID: 144340, Repeated 2 times.
# ID: 144339, Repeated 2 times.
# ID: 143323, Repeated 2 times.
# ID: 143363, Repeated 2 times.
# ID: 143400, Repeated 2 times.
# ID: 143443, Repeated 2 times.
# ID: 143564, Repeated 2 times.
# ID: 143595, Repeated 2 times.
# ID: 143616, Repeated 2 times.
# ID: 143651, Repeated 2 times.
# ID: 143775, Repeated 2 times.
# ID: 143838, Repeated 2 times.
# ID: 143876, Repeated 2 times.
# ID: 143938, Repeated 2 times.
# ID: 143939, Repeated 2 times.
# ID: 143998, Repeated 2 times.
# ID: 144026, Repeated 2 times.
# ID: 144145, Repeated 2 times.
# ID: 144220, Repeated 2 times.
# ID: 144239, Repeated 2 times.
# ID: 144337, Repeated 2 times.
# ID: 145664, Repeated 2 times.
# ID: 145744, Repeated 2 times.
# ID: 147529, Repeated 2 times.
# ID: 146938, Repeated 2 times.
# ID: 146705, Repeated 2 times.
# ID: 146738, Repeated 2 times.
# ID: 146756, Repeated 2 times.
# ID: 146760, Repeated 2 times.
# ID: 146804, Repeated 2 times.
# ID: 146825, Repeated 2 times.
# ID: 146885, Repeated 2 times.
# ID: 146890, Repeated 2 times.
# ID: 146917, Repeated 2 times.
# ID: 146941, Repeated 2 times.
# ID: 145778, Repeated 2 times.
# ID: 146985, Repeated 2 times.
# ID: 147038, Repeated 2 times.
# ID: 147045, Repeated 2 times.
# ID: 147111, Repeated 2 times.
# ID: 147114, Repeated 2 times.
# ID: 147141, Repeated 2 times.
# ID: 147396, Repeated 2 times.
# ID: 147407, Repeated 2 times.
# ID: 147509, Repeated 2 times.
# ID: 146599, Repeated 2 times.
# ID: 146593, Repeated 2 times.
# ID: 146583, Repeated 2 times.
# ID: 146500, Repeated 2 times.
# ID: 145791, Repeated 2 times.
# ID: 145802, Repeated 2 times.
# ID: 145823, Repeated 2 times.
# ID: 145871, Repeated 2 times.
# ID: 145875, Repeated 2 times.
# ID: 145914, Repeated 2 times.
# ID: 145920, Repeated 2 times.
# ID: 145928, Repeated 2 times.
# ID: 146021, Repeated 2 times.
# ID: 146103, Repeated 2 times.
# ID: 146193, Repeated 2 times.
# ID: 146222, Repeated 2 times.
# ID: 146226, Repeated 2 times.
# ID: 146232, Repeated 2 times.
# ID: 146249, Repeated 2 times.
# ID: 146360, Repeated 2 times.
# ID: 146365, Repeated 2 times.
# ID: 146423, Repeated 2 times.
# ID: 146447, Repeated 2 times.
# ID: 134373, Repeated 2 times.
# ID: 134361, Repeated 2 times.
# ID: 117061, Repeated 2 times.
# ID: 123043, Repeated 2 times.
# ID: 122610, Repeated 2 times.
# ID: 122661, Repeated 2 times.
# ID: 122792, Repeated 2 times.
# ID: 122878, Repeated 2 times.
# ID: 122884, Repeated 2 times.
# ID: 122899, Repeated 2 times.
# ID: 122956, Repeated 2 times.
# ID: 122960, Repeated 2 times.
# ID: 122989, Repeated 2 times.
# ID: 123219, Repeated 2 times.
# ID: 123729, Repeated 2 times.
# ID: 123292, Repeated 2 times.
# ID: 123321, Repeated 2 times.
# ID: 123328, Repeated 2 times.
# ID: 123337, Repeated 2 times.
# ID: 123390, Repeated 2 times.
# ID: 123427, Repeated 2 times.
# ID: 123471, Repeated 2 times.
# ID: 123540, Repeated 2 times.
# ID: 123542, Repeated 2 times.
# ID: 122533, Repeated 2 times.
# ID: 122478, Repeated 2 times.
# ID: 122471, Repeated 2 times.
# ID: 122463, Repeated 2 times.
# ID: 121661, Repeated 2 times.
# ID: 121703, Repeated 2 times.
# ID: 121704, Repeated 2 times.
# ID: 121893, Repeated 2 times.
# ID: 121896, Repeated 2 times.
# ID: 121932, Repeated 2 times.
# ID: 121969, Repeated 2 times.
# ID: 122007, Repeated 2 times.
# ID: 122028, Repeated 2 times.
# ID: 122099, Repeated 2 times.
# ID: 122117, Repeated 2 times.
# ID: 122155, Repeated 2 times.
# ID: 122293, Repeated 2 times.
# ID: 122369, Repeated 2 times.
# ID: 122387, Repeated 2 times.
# ID: 122413, Repeated 2 times.
# ID: 122417, Repeated 2 times.
# ID: 122443, Repeated 2 times.
# ID: 122453, Repeated 2 times.
# ID: 123702, Repeated 2 times.
# ID: 123841, Repeated 2 times.
# ID: 121581, Repeated 2 times.
# ID: 125463, Repeated 2 times.
# ID: 125001, Repeated 2 times.
# ID: 125031, Repeated 2 times.
# ID: 125073, Repeated 2 times.
# ID: 125075, Repeated 2 times.
# ID: 125210, Repeated 2 times.
# ID: 125312, Repeated 2 times.
# ID: 125392, Repeated 2 times.
# ID: 125424, Repeated 2 times.
# ID: 125442, Repeated 2 times.
# ID: 125480, Repeated 2 times.
# ID: 123879, Repeated 2 times.
# ID: 125497, Repeated 2 times.
# ID: 125574, Repeated 2 times.
# ID: 125605, Repeated 2 times.
# ID: 125648, Repeated 2 times.
# ID: 125718, Repeated 2 times.
# ID: 125734, Repeated 2 times.
# ID: 125753, Repeated 2 times.
# ID: 125791, Repeated 2 times.
# ID: 125840, Repeated 2 times.
# ID: 124987, Repeated 2 times.
# ID: 124962, Repeated 2 times.
# ID: 124908, Repeated 2 times.
# ID: 124823, Repeated 2 times.
# ID: 123892, Repeated 2 times.
# ID: 123929, Repeated 2 times.
# ID: 123965, Repeated 2 times.
# ID: 124039, Repeated 2 times.
# ID: 124047, Repeated 2 times.
# ID: 124113, Repeated 2 times.
# ID: 124169, Repeated 2 times.
# ID: 124171, Repeated 2 times.
# ID: 124271, Repeated 2 times.
# ID: 124290, Repeated 2 times.
# ID: 124352, Repeated 2 times.
# ID: 124377, Repeated 2 times.
# ID: 124389, Repeated 2 times.
# ID: 124392, Repeated 2 times.
# ID: 124548, Repeated 2 times.
# ID: 124571, Repeated 2 times.
# ID: 124605, Repeated 2 times.
# ID: 124717, Repeated 2 times.
# ID: 124821, Repeated 2 times.
# ID: 121585, Repeated 2 times.
# ID: 121560, Repeated 2 times.
# ID: 125920, Repeated 2 times.
# ID: 118599, Repeated 2 times.
# ID: 118089, Repeated 2 times.
# ID: 118128, Repeated 2 times.
# ID: 118270, Repeated 2 times.
# ID: 118344, Repeated 2 times.
# ID: 118449, Repeated 2 times.
# ID: 118473, Repeated 2 times.
# ID: 118475, Repeated 2 times.
# ID: 118483, Repeated 2 times.
# ID: 118520, Repeated 2 times.
# ID: 118620, Repeated 2 times.
# ID: 119130, Repeated 2 times.
# ID: 118628, Repeated 2 times.
# ID: 118688, Repeated 2 times.
# ID: 118785, Repeated 2 times.
# ID: 118803, Repeated 2 times.
# ID: 118808, Repeated 2 times.
# ID: 118845, Repeated 2 times.
# ID: 118860, Repeated 2 times.
# ID: 118902, Repeated 2 times.
# ID: 119059, Repeated 2 times.
# ID: 118066, Repeated 2 times.
# ID: 118049, Repeated 2 times.
# ID: 118010, Repeated 2 times.
# ID: 118000, Repeated 2 times.
# ID: 117202, Repeated 2 times.
# ID: 117219, Repeated 2 times.
# ID: 117231, Repeated 2 times.
# ID: 117314, Repeated 2 times.
# ID: 117340, Repeated 2 times.
# ID: 117404, Repeated 2 times.
# ID: 117463, Repeated 2 times.
# ID: 117500, Repeated 2 times.
# ID: 117516, Repeated 2 times.
# ID: 117535, Repeated 2 times.
# ID: 117637, Repeated 2 times.
# ID: 117670, Repeated 2 times.
# ID: 117722, Repeated 2 times.
# ID: 117729, Repeated 2 times.
# ID: 117756, Repeated 2 times.
# ID: 117771, Repeated 2 times.
# ID: 117842, Repeated 2 times.
# ID: 117890, Repeated 2 times.
# ID: 117978, Repeated 2 times.
# ID: 119093, Repeated 2 times.
# ID: 119199, Repeated 2 times.
# ID: 121531, Repeated 2 times.
# ID: 120925, Repeated 2 times.
# ID: 120497, Repeated 2 times.
# ID: 120508, Repeated 2 times.
# ID: 120512, Repeated 2 times.
# ID: 120595, Repeated 2 times.
# ID: 120781, Repeated 2 times.
# ID: 120810, Repeated 2 times.
# ID: 120849, Repeated 2 times.
# ID: 120872, Repeated 2 times.
# ID: 120911, Repeated 2 times.
# ID: 120932, Repeated 2 times.
# ID: 119326, Repeated 2 times.
# ID: 120976, Repeated 2 times.
# ID: 121224, Repeated 2 times.
# ID: 121234, Repeated 2 times.
# ID: 121241, Repeated 2 times.
# ID: 121293, Repeated 2 times.
# ID: 121303, Repeated 2 times.
# ID: 121376, Repeated 2 times.
# ID: 121410, Repeated 2 times.
# ID: 121509, Repeated 2 times.
# ID: 120362, Repeated 2 times.
# ID: 120218, Repeated 2 times.
# ID: 120211, Repeated 2 times.
# ID: 120190, Repeated 2 times.
# ID: 119364, Repeated 2 times.
# ID: 119495, Repeated 2 times.
# ID: 119587, Repeated 2 times.
# ID: 119588, Repeated 2 times.
# ID: 119673, Repeated 2 times.
# ID: 119701, Repeated 2 times.
# ID: 119720, Repeated 2 times.
# ID: 119724, Repeated 2 times.
# ID: 119725, Repeated 2 times.
# ID: 119749, Repeated 2 times.
# ID: 119769, Repeated 2 times.
# ID: 119779, Repeated 2 times.
# ID: 119971, Repeated 2 times.
# ID: 120051, Repeated 2 times.
# ID: 120067, Repeated 2 times.
# ID: 120107, Repeated 2 times.
# ID: 120159, Repeated 2 times.
# ID: 120161, Repeated 2 times.
# ID: 120170, Repeated 2 times.
# ID: 125901, Repeated 2 times.
# ID: 125939, Repeated 2 times.
# ID: 134273, Repeated 2 times.
# ID: 131653, Repeated 2 times.
# ID: 131245, Repeated 2 times.
# ID: 131289, Repeated 2 times.
# ID: 131290, Repeated 2 times.
# ID: 131359, Repeated 2 times.
# ID: 131374, Repeated 2 times.
# ID: 131399, Repeated 2 times.
# ID: 131483, Repeated 2 times.
# ID: 131623, Repeated 2 times.
# ID: 131632, Repeated 2 times.
# ID: 131732, Repeated 2 times.
# ID: 132050, Repeated 2 times.
# ID: 131744, Repeated 2 times.
# ID: 131747, Repeated 2 times.
# ID: 131794, Repeated 2 times.
# ID: 131801, Repeated 2 times.
# ID: 131831, Repeated 2 times.
# ID: 131853, Repeated 2 times.
# ID: 131898, Repeated 2 times.
# ID: 131907, Repeated 2 times.
# ID: 131941, Repeated 2 times.
# ID: 131205, Repeated 2 times.
# ID: 131082, Repeated 2 times.
# ID: 131079, Repeated 2 times.
# ID: 131078, Repeated 2 times.
# ID: 130374, Repeated 2 times.
# ID: 130404, Repeated 2 times.
# ID: 130479, Repeated 2 times.
# ID: 130506, Repeated 2 times.
# ID: 130532, Repeated 2 times.
# ID: 130537, Repeated 2 times.
# ID: 130590, Repeated 2 times.
# ID: 130601, Repeated 2 times.
# ID: 130628, Repeated 2 times.
# ID: 130767, Repeated 2 times.
# ID: 130796, Repeated 2 times.
# ID: 130809, Repeated 2 times.
# ID: 130888, Repeated 2 times.
# ID: 130896, Repeated 2 times.
# ID: 130959, Repeated 2 times.
# ID: 130978, Repeated 2 times.
# ID: 131007, Repeated 2 times.
# ID: 131008, Repeated 2 times.
# ID: 131037, Repeated 2 times.
# ID: 131944, Repeated 2 times.
# ID: 132098, Repeated 2 times.
# ID: 130322, Repeated 2 times.
# ID: 133459, Repeated 2 times.
# ID: 133053, Repeated 2 times.
# ID: 133092, Repeated 2 times.
# ID: 133190, Repeated 2 times.
# ID: 133251, Repeated 2 times.
# ID: 133252, Repeated 2 times.
# ID: 133272, Repeated 2 times.
# ID: 133284, Repeated 2 times.
# ID: 133351, Repeated 2 times.
# ID: 133447, Repeated 2 times.
# ID: 133474, Repeated 2 times.
# ID: 132101, Repeated 2 times.
# ID: 133476, Repeated 2 times.
# ID: 133604, Repeated 2 times.
# ID: 133650, Repeated 2 times.
# ID: 133672, Repeated 2 times.
# ID: 133891, Repeated 2 times.
# ID: 133894, Repeated 2 times.
# ID: 134078, Repeated 2 times.
# ID: 134242, Repeated 2 times.
# ID: 134257, Repeated 2 times.
# ID: 133038, Repeated 2 times.
# ID: 133018, Repeated 2 times.
# ID: 132983, Repeated 2 times.
# ID: 132925, Repeated 2 times.
# ID: 132223, Repeated 2 times.
# ID: 132297, Repeated 2 times.
# ID: 132298, Repeated 2 times.
# ID: 132305, Repeated 2 times.
# ID: 132327, Repeated 2 times.
# ID: 132352, Repeated 2 times.
# ID: 132381, Repeated 2 times.
# ID: 132397, Repeated 2 times.
# ID: 132474, Repeated 2 times.
# ID: 132514, Repeated 2 times.
# ID: 132525, Repeated 2 times.
# ID: 132529, Repeated 2 times.
# ID: 132551, Repeated 2 times.
# ID: 132627, Repeated 2 times.
# ID: 132720, Repeated 2 times.
# ID: 132774, Repeated 2 times.
# ID: 132848, Repeated 2 times.
# ID: 132853, Repeated 2 times.
# ID: 132880, Repeated 2 times.
# ID: 130356, Repeated 2 times.
# ID: 130268, Repeated 2 times.
# ID: 125961, Repeated 2 times.
# ID: 127729, Repeated 2 times.
# ID: 127287, Repeated 2 times.
# ID: 127347, Repeated 2 times.
# ID: 127402, Repeated 2 times.
# ID: 127425, Repeated 2 times.
# ID: 127530, Repeated 2 times.
# ID: 127542, Repeated 2 times.
# ID: 127583, Repeated 2 times.
# ID: 127607, Repeated 2 times.
# ID: 127631, Repeated 2 times.
# ID: 127741, Repeated 2 times.
# ID: 128146, Repeated 2 times.
# ID: 127774, Repeated 2 times.
# ID: 127792, Repeated 2 times.
# ID: 127854, Repeated 2 times.
# ID: 127878, Repeated 2 times.
# ID: 127884, Repeated 2 times.
# ID: 127911, Repeated 2 times.
# ID: 127933, Repeated 2 times.
# ID: 127943, Repeated 2 times.
# ID: 128032, Repeated 2 times.
# ID: 127200, Repeated 2 times.
# ID: 127190, Repeated 2 times.
# ID: 127188, Repeated 2 times.
# ID: 127174, Repeated 2 times.
# ID: 125962, Repeated 2 times.
# ID: 125974, Repeated 2 times.
# ID: 125998, Repeated 2 times.
# ID: 126053, Repeated 2 times.
# ID: 126061, Repeated 2 times.
# ID: 126145, Repeated 2 times.
# ID: 126251, Repeated 2 times.
# ID: 126253, Repeated 2 times.
# ID: 126307, Repeated 2 times.
# ID: 126357, Repeated 2 times.
# ID: 126481, Repeated 2 times.
# ID: 126484, Repeated 2 times.
# ID: 126677, Repeated 2 times.
# ID: 126742, Repeated 2 times.
# ID: 126803, Repeated 2 times.
# ID: 126829, Repeated 2 times.
# ID: 126872, Repeated 2 times.
# ID: 127053, Repeated 2 times.
# ID: 127130, Repeated 2 times.
# ID: 128064, Repeated 2 times.
# ID: 128243, Repeated 2 times.
# ID: 130137, Repeated 2 times.
# ID: 129628, Repeated 2 times.
# ID: 129284, Repeated 2 times.
# ID: 129285, Repeated 2 times.
# ID: 129309, Repeated 2 times.
# ID: 129411, Repeated 2 times.
# ID: 129455, Repeated 2 times.
# ID: 129462, Repeated 2 times.
# ID: 129483, Repeated 2 times.
# ID: 129485, Repeated 2 times.
# ID: 129602, Repeated 2 times.
# ID: 129671, Repeated 2 times.
# ID: 128248, Repeated 2 times.
# ID: 129743, Repeated 2 times.
# ID: 129864, Repeated 2 times.
# ID: 129873, Repeated 2 times.
# ID: 129924, Repeated 2 times.
# ID: 129949, Repeated 2 times.
# ID: 129972, Repeated 2 times.
# ID: 129977, Repeated 2 times.
# ID: 129997, Repeated 2 times.
# ID: 130025, Repeated 2 times.
# ID: 129282, Repeated 2 times.
# ID: 129251, Repeated 2 times.
# ID: 129080, Repeated 2 times.
# ID: 128923, Repeated 2 times.
# ID: 128255, Repeated 2 times.
# ID: 128300, Repeated 2 times.
# ID: 128311, Repeated 2 times.
# ID: 128359, Repeated 2 times.
# ID: 128392, Repeated 2 times.
# ID: 128419, Repeated 2 times.
# ID: 128434, Repeated 2 times.
# ID: 128560, Repeated 2 times.
# ID: 128592, Repeated 2 times.
# ID: 128608, Repeated 2 times.
# ID: 128613, Repeated 2 times.
# ID: 128750, Repeated 2 times.
# ID: 128807, Repeated 2 times.
# ID: 128832, Repeated 2 times.
# ID: 128874, Repeated 2 times.
# ID: 128892, Repeated 2 times.
# ID: 128897, Repeated 2 times.
# ID: 128919, Repeated 2 times.
# ID: 128920, Repeated 2 times.
# ID: 77591, Repeated 2 times.
# ID: 128583, Repeated 2 times.
# ID: 77565, Repeated 2 times.
# ID: 25765, Repeated 2 times.
# ID: 25300, Repeated 2 times.
# ID: 25326, Repeated 2 times.
# ID: 25335, Repeated 2 times.
# ID: 25403, Repeated 2 times.
# ID: 25476, Repeated 2 times.
# ID: 25531, Repeated 2 times.
# ID: 25648, Repeated 2 times.
# ID: 25683, Repeated 2 times.
# ID: 25719, Repeated 2 times.
# ID: 25767, Repeated 2 times.
# ID: 25203, Repeated 2 times.
# ID: 25774, Repeated 2 times.
# ID: 25864, Repeated 2 times.
# ID: 25878, Repeated 2 times.
# ID: 25890, Repeated 2 times.
# ID: 25891, Repeated 2 times.
# ID: 25931, Repeated 2 times.
# ID: 25942, Repeated 2 times.
# ID: 26011, Repeated 2 times.
# ID: 26028, Repeated 2 times.
# ID: 25226, Repeated 2 times.
# ID: 25188, Repeated 2 times.
# ID: 37434, Repeated 2 times.
# ID: 24569, Repeated 2 times.
# ID: 24282, Repeated 2 times.
# ID: 24285, Repeated 2 times.
# ID: 24414, Repeated 2 times.
# ID: 24454, Repeated 2 times.
# ID: 24455, Repeated 2 times.
# ID: 24456, Repeated 2 times.
# ID: 24522, Repeated 2 times.
# ID: 24550, Repeated 2 times.
# ID: 24558, Repeated 2 times.
# ID: 24605, Repeated 2 times.
# ID: 25128, Repeated 2 times.
# ID: 24610, Repeated 2 times.
# ID: 24767, Repeated 2 times.
# ID: 24866, Repeated 2 times.
# ID: 24944, Repeated 2 times.
# ID: 24952, Repeated 2 times.
# ID: 24995, Repeated 2 times.
# ID: 25009, Repeated 2 times.
# ID: 25076, Repeated 2 times.
# ID: 25084, Repeated 2 times.
# ID: 26245, Repeated 2 times.
# ID: 26339, Repeated 2 times.
# ID: 26373, Repeated 2 times.
# ID: 27794, Repeated 2 times.
# ID: 27438, Repeated 2 times.
# ID: 27462, Repeated 2 times.
# ID: 27498, Repeated 2 times.
# ID: 27504, Repeated 2 times.
# ID: 27533, Repeated 2 times.
# ID: 27599, Repeated 2 times.
# ID: 27694, Repeated 2 times.
# ID: 27702, Repeated 2 times.
# ID: 27727, Repeated 2 times.
# ID: 27826, Repeated 2 times.
# ID: 26430, Repeated 2 times.
# ID: 27896, Repeated 2 times.
# ID: 27898, Repeated 2 times.
# ID: 27995, Repeated 2 times.
# ID: 28076, Repeated 2 times.
# ID: 28146, Repeated 2 times.
# ID: 28208, Repeated 2 times.
# ID: 28256, Repeated 2 times.
# ID: 28292, Repeated 2 times.
# ID: 28304, Repeated 2 times.
# ID: 27430, Repeated 2 times.
# ID: 27389, Repeated 2 times.
# ID: 27386, Repeated 2 times.
# ID: 27373, Repeated 2 times.
# ID: 26431, Repeated 2 times.
# ID: 26482, Repeated 2 times.
# ID: 26523, Repeated 2 times.
# ID: 26574, Repeated 2 times.
# ID: 26589, Repeated 2 times.
# ID: 26603, Repeated 2 times.
# ID: 26646, Repeated 2 times.
# ID: 26647, Repeated 2 times.
# ID: 26690, Repeated 2 times.
# ID: 26757, Repeated 2 times.
# ID: 26769, Repeated 2 times.
# ID: 26841, Repeated 2 times.
# ID: 26943, Repeated 2 times.
# ID: 27017, Repeated 2 times.
# ID: 27029, Repeated 2 times.
# ID: 27056, Repeated 2 times.
# ID: 27063, Repeated 2 times.
# ID: 27150, Repeated 2 times.
# ID: 27280, Repeated 2 times.
# ID: 24276, Repeated 2 times.
# ID: 24152, Repeated 2 times.
# ID: 23956, Repeated 2 times.
# ID: 21212, Repeated 2 times.
# ID: 20850, Repeated 2 times.
# ID: 20891, Repeated 2 times.
# ID: 20978, Repeated 2 times.
# ID: 20999, Repeated 2 times.
# ID: 21006, Repeated 2 times.
# ID: 21012, Repeated 2 times.
# ID: 21091, Repeated 2 times.
# ID: 21097, Repeated 2 times.
# ID: 21168, Repeated 2 times.
# ID: 21298, Repeated 2 times.
# ID: 22071, Repeated 2 times.
# ID: 21427, Repeated 2 times.
# ID: 21436, Repeated 2 times.
# ID: 21638, Repeated 2 times.
# ...
# ID: 73638, Repeated 2 times.
# ID: 73844, Repeated 2 times.
# ID: 74605, Repeated 2 times.
# ID: 73905, Repeated 2 times.
# ID: 73925, Repeated 2 times.
# ID: 74012, Repeated 2 times.
# ID: 74021, Repeated 2 times.
# ID: 74168, Repeated 2 times.
# ID: 74182, Repeated 2 times.
# ID: 74206, Repeated 2 times.
# ID: 74297, Repeated 2 times.
# ID: 74339, Repeated 2 times.
# ID: 73228, Repeated 2 times.
# ID: 73219, Repeated 2 times.
# ID: 73215, Repeated 2 times.
# ID: 73153, Repeated 2 times.
# ID: 71664, Repeated 2 times.
# ID: 71827, Repeated 2 times.
# ID: 71923, Repeated 2 times.
# ID: 71925, Repeated 2 times.
# ID: 72074, Repeated 2 times.
# ID: 72252, Repeated 2 times.
# ID: 72299, Repeated 2 times.
# ID: 72472, Repeated 2 times.
# ID: 72514, Repeated 2 times.
# ID: 72542, Repeated 2 times.
# ID: 72555, Repeated 2 times.
# ID: 72611, Repeated 2 times.
# ID: 72650, Repeated 2 times.
# ID: 72665, Repeated 2 times.
# ID: 72688, Repeated 2 times.
# ID: 72796, Repeated 2 times.
# ID: 72810, Repeated 2 times.
# ID: 72831, Repeated 2 times.
# ID: 72956, Repeated 2 times.
# ID: 74418, Repeated 2 times.
# ID: 74639, Repeated 2 times.
# ID: 71545, Repeated 2 times.
# ID: 76534, Repeated 2 times.
# ID: 76243, Repeated 2 times.
# ID: 76274, Repeated 2 times.
# ID: 76288, Repeated 2 times.
# ID: 76332, Repeated 2 times.
# ID: 76366, Repeated 2 times.
# ID: 76372, Repeated 2 times.
# ID: 76419, Repeated 2 times.
# ID: 76427, Repeated 2 times.
# ID: 76436, Repeated 2 times.
# ID: 76545, Repeated 2 times.
# ID: 74684, Repeated 2 times.
# ID: 76579, Repeated 2 times.
# ID: 76641, Repeated 2 times.
# ID: 76760, Repeated 2 times.
# ID: 76873, Repeated 2 times.
# ID: 76995, Repeated 2 times.
# ID: 77225, Repeated 2 times.
# ID: 37477, Repeated 2 times.
# ID: 77325, Repeated 2 times.
# ID: 77421, Repeated 2 times.
# ID: 76208, Repeated 2 times.
# ID: 76187, Repeated 2 times.
# ID: 76185, Repeated 2 times.
# ID: 76001, Repeated 2 times.
# ID: 74694, Repeated 2 times.
# ID: 74704, Repeated 2 times.
# ID: 74751, Repeated 2 times.
# ID: 74811, Repeated 2 times.
# ID: 74883, Repeated 2 times.
# ID: 74911, Repeated 2 times.
# ID: 74957, Repeated 2 times.
# ID: 75112, Repeated 2 times.
# ID: 75140, Repeated 2 times.
# ID: 75406, Repeated 2 times.
# ID: 75435, Repeated 2 times.
# ID: 75489, Repeated 2 times.
# ID: 75577, Repeated 2 times.
# ID: 75608, Repeated 2 times.
# ID: 75763, Repeated 2 times.
# ID: 75775, Repeated 2 times.
# ID: 75817, Repeated 2 times.
# ID: 75844, Repeated 2 times.
# ID: 75946, Repeated 2 times.
# ID: 71580, Repeated 2 times.
# ID: 71521, Repeated 2 times.
# ID: 66522, Repeated 2 times.
# ID: 68089, Repeated 2 times.
# ID: 67423, Repeated 2 times.
# ID: 67461, Repeated 2 times.
# ID: 67482, Repeated 2 times.
# ID: 67512, Repeated 2 times.
# ID: 67676, Repeated 2 times.
# ID: 67813, Repeated 2 times.
# ID: 67925, Repeated 2 times.
# ID: 67985, Repeated 2 times.
# ID: 68083, Repeated 2 times.
# ID: 68097, Repeated 2 times.
# ID: 68344, Repeated 2 times.
# ID: 68109, Repeated 2 times.
# ID: 68155, Repeated 2 times.
# ID: 68174, Repeated 2 times.
# ID: 68189, Repeated 2 times.
# ID: 68204, Repeated 2 times.
# ID: 68234, Repeated 2 times.
# ID: 68252, Repeated 2 times.
# ID: 68286, Repeated 2 times.
# ID: 68325, Repeated 2 times.
# ID: 67380, Repeated 2 times.
# ID: 67324, Repeated 2 times.
# ID: 67313, Repeated 2 times.
# ID: 67268, Repeated 2 times.
# ID: 66572, Repeated 2 times.
# ID: 66609, Repeated 2 times.
# ID: 66656, Repeated 2 times.
# ID: 66672, Repeated 2 times.
# ID: 66750, Repeated 2 times.
# ID: 66766, Repeated 2 times.
# ID: 66777, Repeated 2 times.
# ID: 66783, Repeated 2 times.
# ID: 66853, Repeated 2 times.
# ID: 66937, Repeated 2 times.
# ID: 66977, Repeated 2 times.
# ID: 67005, Repeated 2 times.
# ID: 67006, Repeated 2 times.
# ID: 67026, Repeated 2 times.
# ID: 67044, Repeated 2 times.
# ID: 67054, Repeated 2 times.
# ID: 67121, Repeated 2 times.
# ID: 67157, Repeated 2 times.
# ID: 67192, Repeated 2 times.
# ID: 68342, Repeated 2 times.
# ID: 68375, Repeated 2 times.
# ID: 71316, Repeated 2 times.
# ID: 70712, Repeated 2 times.
# ID: 70303, Repeated 2 times.
# ID: 70336, Repeated 2 times.
# ID: 70443, Repeated 2 times.
# ID: 70537, Repeated 2 times.
# ID: 70554, Repeated 2 times.
# ID: 70630, Repeated 2 times.
# ID: 70650, Repeated 2 times.
# ID: 70656, Repeated 2 times.
# ID: 70709, Repeated 2 times.
# ID: 70908, Repeated 2 times.
# ID: 68388, Repeated 2 times.
# ID: 70958, Repeated 2 times.
# ID: 71019, Repeated 2 times.
# ID: 71042, Repeated 2 times.
# ID: 71130, Repeated 2 times.
# ID: 71163, Repeated 2 times.
# ID: 71219, Repeated 2 times.
# ID: 71221, Repeated 2 times.
# ID: 71241, Repeated 2 times.
# ID: 71306, Repeated 2 times.
# ID: 70253, Repeated 2 times.
# ID: 70164, Repeated 2 times.
# ID: 70156, Repeated 2 times.
# ID: 70155, Repeated 2 times.
# ID: 68485, Repeated 2 times.
# ID: 68586, Repeated 2 times.
# ID: 68677, Repeated 2 times.
# ID: 68843, Repeated 2 times.
# ID: 68943, Repeated 2 times.
# ID: 69015, Repeated 2 times.
# ID: 69231, Repeated 2 times.
# ID: 69329, Repeated 2 times.
# ID: 69330, Repeated 2 times.
# ID: 69835, Repeated 2 times.
# ID: 69855, Repeated 2 times.
# ID: 69945, Repeated 2 times.
# ID: 69974, Repeated 2 times.
# ID: 70019, Repeated 2 times.
# ID: 70059, Repeated 2 times.
# ID: 70068, Repeated 2 times.
# ID: 70083, Repeated 2 times.
# ID: 70098, Repeated 2 times.
# ID: 70100, Repeated 2 times.
# ID: 55778, Repeated 2 times.
# ID: 69753, Repeated 2 times.
# ID: 55754, Repeated 2 times.
# ID: 43931, Repeated 2 times.
# ID: 43525, Repeated 2 times.
# ID: 43538, Repeated 2 times.
# ID: 43555, Repeated 2 times.
# ID: 43602, Repeated 2 times.
# ID: 43621, Repeated 2 times.
# ID: 43632, Repeated 2 times.
# ID: 43711, Repeated 2 times.
# ID: 43744, Repeated 2 times.
# ID: 43916, Repeated 2 times.
# ID: 44026, Repeated 2 times.
# ID: 44355, Repeated 2 times.
# ID: 44096, Repeated 2 times.
# ID: 44117, Repeated 2 times.
# ID: 44129, Repeated 2 times.
# ID: 44141, Repeated 2 times.
# ID: 44150, Repeated 2 times.
# ID: 44194, Repeated 2 times.
# ID: 44213, Repeated 2 times.
# ID: 44240, Repeated 2 times.
# ID: 44248, Repeated 2 times.
# ID: 43361, Repeated 2 times.
# ID: 43309, Repeated 2 times.
# ID: 43242, Repeated 2 times.
# ID: 43150, Repeated 2 times.
# ID: 42305, Repeated 2 times.
# ID: 42339, Repeated 2 times.
# ID: 42343, Repeated 2 times.
# ID: 42425, Repeated 2 times.
# ID: 42487, Repeated 2 times.
# ID: 42551, Repeated 2 times.
# ID: 42595, Repeated 2 times.
# ID: 42597, Repeated 2 times.
# ID: 42698, Repeated 2 times.
# ID: 42700, Repeated 2 times.
# ID: 42702, Repeated 2 times.
# ID: 42704, Repeated 2 times.
# ID: 42785, Repeated 2 times.
# ID: 42806, Repeated 2 times.
# ID: 42924, Repeated 2 times.
# ID: 42969, Repeated 2 times.
# ID: 43021, Repeated 2 times.
# ID: 43087, Repeated 2 times.
# ID: 43130, Repeated 2 times.
# ID: 44312, Repeated 2 times.
# ID: 44359, Repeated 2 times.
# ID: 42224, Repeated 2 times.
# ID: 45570, Repeated 2 times.
# ID: 45283, Repeated 2 times.
# ID: 45309, Repeated 2 times.
# ID: 45346, Repeated 2 times.
# ID: 45358, Repeated 2 times.
# ID: 45364, Repeated 2 times.
# ID: 45370, Repeated 2 times.
# ID: 45451, Repeated 2 times.
# ID: 45467, Repeated 2 times.
# ID: 45477, Repeated 2 times.
# ID: 45649, Repeated 2 times.
# ID: 44363, Repeated 2 times.
# ID: 45706, Repeated 2 times.
# ID: 45737, Repeated 2 times.
# ID: 45889, Repeated 2 times.
# ID: 45928, Repeated 2 times.
# ID: 45944, Repeated 2 times.
# ID: 45958, Repeated 2 times.
# ID: 46007, Repeated 2 times.
# ID: 46017, Repeated 2 times.
# ID: 46021, Repeated 2 times.
# ID: 45236, Repeated 2 times.
# ID: 45184, Repeated 2 times.
# ID: 45168, Repeated 2 times.
# ID: 45144, Repeated 2 times.
# ID: 44405, Repeated 2 times.
# ID: 44433, Repeated 2 times.
# ID: 44480, Repeated 2 times.
# ID: 44524, Repeated 2 times.
# ID: 44554, Repeated 2 times.
# ID: 44582, Repeated 2 times.
# ID: 44641, Repeated 2 times.
# ID: 44717, Repeated 2 times.
# ID: 44824, Repeated 2 times.
# ID: 44846, Repeated 2 times.
# ID: 44851, Repeated 2 times.
# ID: 44960, Repeated 2 times.
# ID: 45027, Repeated 2 times.
# ID: 45056, Repeated 2 times.
# ID: 45057, Repeated 2 times.
# ID: 45063, Repeated 2 times.
# ID: 45073, Repeated 2 times.
# ID: 45092, Repeated 2 times.
# ID: 45113, Repeated 2 times.
# ID: 42282, Repeated 2 times.
# ID: 42216, Repeated 2 times.
# ID: 46132, Repeated 2 times.
# ID: 39144, Repeated 2 times.
# ID: 38806, Repeated 2 times.
# ID: 38824, Repeated 2 times.
# ID: 38885, Repeated 2 times.
# ID: 38933, Repeated 2 times.
# ID: 38960, Repeated 2 times.
# ID: 38982, Repeated 2 times.
# ID: 38987, Repeated 2 times.
# ID: 39109, Repeated 2 times.
# ID: 39130, Repeated 2 times.
# ID: 39182, Repeated 2 times.
# ID: 39640, Repeated 2 times.
# ID: 39309, Repeated 2 times.
# ID: 39368, Repeated 2 times.
# ID: 39371, Repeated 2 times.
# ID: 39402, Repeated 2 times.
# ID: 39450, Repeated 2 times.
# ID: 39476, Repeated 2 times.
# ID: 39519, Repeated 2 times.
# ID: 39537, Repeated 2 times.
# ID: 39551, Repeated 2 times.
# ID: 38803, Repeated 2 times.
# ID: 38742, Repeated 2 times.
# ID: 38681, Repeated 2 times.
# ID: 38680, Repeated 2 times.
# ID: 37750, Repeated 2 times.
# ID: 55692, Repeated 2 times.
# ID: 37927, Repeated 2 times.
# ID: 38035, Repeated 2 times.
# ID: 38069, Repeated 2 times.
# ID: 38089, Repeated 2 times.
# ID: 38103, Repeated 2 times.
# ID: 38112, Repeated 2 times.
# ID: 38121, Repeated 2 times.
# ID: 38213, Repeated 2 times.
# ID: 38277, Repeated 2 times.
# ID: 38307, Repeated 2 times.
# ID: 38512, Repeated 2 times.
# ID: 38526, Repeated 2 times.
# ID: 38593, Repeated 2 times.
# ID: 38606, Repeated 2 times.
# ID: 38624, Repeated 2 times.
# ID: 38648, Repeated 2 times.
# ID: 38675, Repeated 2 times.
# ID: 39598, Repeated 2 times.
# ID: 39667, Repeated 2 times.
# ID: 42208, Repeated 2 times.
# ID: 41726, Repeated 2 times.
# ID: 41108, Repeated 2 times.
# ID: 41254, Repeated 2 times.
# ID: 41304, Repeated 2 times.
# ID: 41313, Repeated 2 times.
# ID: 41327, Repeated 2 times.
# ID: 41405, Repeated 2 times.
# ID: 41477, Repeated 2 times.
# ID: 41587, Repeated 2 times.
# ID: 41595, Repeated 2 times.
# ID: 41750, Repeated 2 times.
# ID: 39753, Repeated 2 times.
# ID: 41782, Repeated 2 times.
# ID: 41825, Repeated 2 times.
# ID: 41963, Repeated 2 times.
# ID: 42067, Repeated 2 times.
# ID: 42084, Repeated 2 times.
# ID: 42127, Repeated 2 times.
# ID: 42130, Repeated 2 times.
# ID: 42173, Repeated 2 times.
# ID: 42207, Repeated 2 times.
# ID: 41016, Repeated 2 times.
# ID: 40956, Repeated 2 times.
# ID: 40908, Repeated 2 times.
# ID: 40903, Repeated 2 times.
# ID: 39765, Repeated 2 times.
# ID: 39782, Repeated 2 times.
# ID: 39914, Repeated 2 times.
# ID: 39920, Repeated 2 times.
# ID: 39955, Repeated 2 times.
# ID: 39958, Repeated 2 times.
# ID: 39989, Repeated 2 times.
# ID: 39994, Repeated 2 times.
# ID: 40020, Repeated 2 times.
# ID: 40026, Repeated 2 times.
# ID: 40116, Repeated 2 times.
# ID: 40272, Repeated 2 times.
# ID: 40466, Repeated 2 times.
# ID: 40501, Repeated 2 times.
# ID: 40553, Repeated 2 times.
# ID: 40631, Repeated 2 times.
# ID: 40695, Repeated 2 times.
# ID: 40718, Repeated 2 times.
# ID: 40833, Repeated 2 times.
# ID: 46096, Repeated 2 times.
# ID: 40698, Repeated 2 times.
# ID: 46149, Repeated 2 times.
# ID: 52531, Repeated 2 times.
# ID: 52003, Repeated 2 times.
# ID: 52176, Repeated 2 times.
# ID: 52373, Repeated 2 times.
# ID: 52396, Repeated 2 times.
# ID: 52402, Repeated 2 times.
# ID: 52478, Repeated 2 times.
# ID: 52482, Repeated 2 times.
# ID: 52492, Repeated 2 times.
# ID: 52521, Repeated 2 times.
# ID: 52550, Repeated 2 times.
# ID: 51859, Repeated 2 times.
# ID: 52626, Repeated 2 times.
# ID: 52628, Repeated 2 times.
# ID: 52695, Repeated 2 times.
# ID: 52714, Repeated 2 times.
# ID: 52736, Repeated 2 times.
# ID: 52752, Repeated 2 times.
# ID: 52798, Repeated 2 times.
# ID: 52819, Repeated 2 times.
# ID: 52822, Repeated 2 times.
# ID: 51925, Repeated 2 times.
# ID: 51574, Repeated 2 times.
# ID: 50413, Repeated 2 times.
# ID: 50979, Repeated 2 times.
# ID: 50466, Repeated 2 times.
# ID: 50499, Repeated 2 times.
# ID: 50605, Repeated 2 times.
# ID: 50624, Repeated 2 times.
# ID: 50635, Repeated 2 times.
# ID: 50690, Repeated 2 times.
# ID: 50755, Repeated 2 times.
# ID: 50786, Repeated 2 times.
# ID: 50939, Repeated 2 times.
# ID: 50982, Repeated 2 times.
# ID: 51571, Repeated 2 times.
# ID: 51122, Repeated 2 times.
# ID: 51209, Repeated 2 times.
# ID: 51314, Repeated 2 times.
# ID: 51396, Repeated 2 times.
# ID: 51416, Repeated 2 times.
# ID: 51421, Repeated 2 times.
# ID: 51423, Repeated 2 times.
# ID: 51437, Repeated 2 times.
# ID: 51531, Repeated 2 times.
# ID: 52984, Repeated 2 times.
# ID: 53012, Repeated 2 times.
# ID: 53086, Repeated 2 times.
# ID: 55112, Repeated 2 times.
# ID: 54527, Repeated 2 times.
# ID: 54545, Repeated 2 times.
# ID: 54647, Repeated 2 times.
# ID: 54650, Repeated 2 times.
# ID: 54711, Repeated 2 times.
# ID: 54798, Repeated 2 times.
# ID: 54861, Repeated 2 times.
# ID: 55017, Repeated 2 times.
# ID: 55078, Repeated 2 times.
# ID: 55131, Repeated 2 times.
# ID: 53099, Repeated 2 times.
# ID: 55147, Repeated 2 times.
# ID: 55216, Repeated 2 times.
# ID: 55234, Repeated 2 times.
# ID: 55337, Repeated 2 times.
# ID: 55356, Repeated 2 times.
# ID: 55451, Repeated 2 times.
# ID: 46173, Repeated 2 times.
# ID: 55592, Repeated 2 times.
# ID: 55662, Repeated 2 times.
# ID: 54495, Repeated 2 times.
# ID: 54479, Repeated 2 times.
# ID: 54443, Repeated 2 times.
# ID: 54403, Repeated 2 times.
# ID: 53321, Repeated 2 times.
# ID: 53397, Repeated 2 times.
# ID: 53572, Repeated 2 times.
# ID: 53577, Repeated 2 times.
# ID: 53600, Repeated 2 times.
# ID: 53618, Repeated 2 times.
# ID: 53750, Repeated 2 times.
# ID: 53833, Repeated 2 times.
# ID: 53856, Repeated 2 times.
# ID: 53938, Repeated 2 times.
# ID: 53982, Repeated 2 times.
# ID: 54017, Repeated 2 times.
# ID: 54043, Repeated 2 times.
# ID: 54138, Repeated 2 times.
# ID: 54160, Repeated 2 times.
# ID: 54161, Repeated 2 times.
# ID: 54207, Repeated 2 times.
# ID: 54251, Repeated 2 times.
# ID: 54257, Repeated 2 times.
# ID: 50455, Repeated 2 times.
# ID: 37630, Repeated 2 times.
# ID: 50380, Repeated 2 times.
# ID: 47510, Repeated 2 times.
# ID: 47252, Repeated 2 times.
# ID: 47290, Repeated 2 times.
# ID: 47306, Repeated 2 times.
# ID: 47384, Repeated 2 times.
# ID: 47407, Repeated 2 times.
# ID: 47457, Repeated 2 times.
# ID: 47467, Repeated 2 times.
# ID: 47468, Repeated 2 times.
# ID: 47505, Repeated 2 times.
# ID: 47549, Repeated 2 times.
# ID: 47238, Repeated 2 times.
# ID: 47665, Repeated 2 times.
# ID: 47671, Repeated 2 times.
# ID: 47742, Repeated 2 times.
# ID: 47750, Repeated 2 times.
# ID: 47774, Repeated 2 times.
# ID: 47780, Repeated 2 times.
# ID: 47960, Repeated 2 times.
# ID: 47987, Repeated 2 times.
# ID: 47994, Repeated 2 times.
# ID: 47246, Repeated 2 times.
# ID: 47223, Repeated 2 times.
# ID: 48116, Repeated 2 times.
# ID: 46648, Repeated 2 times.
# ID: 50366, Repeated 2 times.
# ID: 46191, Repeated 2 times.
# ID: 46310, Repeated 2 times.
# ID: 46345, Repeated 2 times.
# ID: 46382, Repeated 2 times.
# ID: 46386, Repeated 2 times.
# ID: 46546, Repeated 2 times.
# ID: 46554, Repeated 2 times.
# ID: 46576, Repeated 2 times.
# ID: 46706, Repeated 2 times.
# ID: 47151, Repeated 2 times.
# ID: 46841, Repeated 2 times.
# ID: 46868, Repeated 2 times.
# ID: 46879, Repeated 2 times.
# ID: 46911, Repeated 2 times.
# ID: 46937, Repeated 2 times.
# ID: 46975, Repeated 2 times.
# ID: 47071, Repeated 2 times.
# ID: 47098, Repeated 2 times.
# ID: 47103, Repeated 2 times.
# ID: 48102, Repeated 2 times.
# ID: 46174, Repeated 2 times.
# ID: 48143, Repeated 2 times.
# ID: 49171, Repeated 2 times.
# ID: 49262, Repeated 2 times.
# ID: 49271, Repeated 2 times.
# ID: 49345, Repeated 2 times.
# ID: 49367, Repeated 2 times.
# ID: 49407, Repeated 2 times.
# ID: 49585, Repeated 2 times.
# ID: 49598, Repeated 2 times.
# ID: 49683, Repeated 2 times.
# ID: 49871, Repeated 2 times.
# ID: 49912, Repeated 2 times.
# ID: 49931, Repeated 2 times.
# ID: 50001, Repeated 2 times.
# ID: 50011, Repeated 2 times.
# ID: 50015, Repeated 2 times.
# ID: 50091, Repeated 2 times.
# ID: 50129, Repeated 2 times.
# ID: 50288, Repeated 2 times.
# ID: 48167, Repeated 2 times.
# ID: 50137, Repeated 2 times.
# ID: 49256, Repeated 2 times.
# ID: 49886, Repeated 2 times.
# ID: 49136, Repeated 2 times.
# ID: 50218, Repeated 2 times.
# ID: 48359, Repeated 2 times.
# ID: 48314, Repeated 2 times.
# ID: 49098, Repeated 2 times.
# ID: 48426, Repeated 2 times.
# ID: 48519, Repeated 2 times.
# ID: 37528, Repeated 2 times.
# ID: 48589, Repeated 2 times.
# ID: 48615, Repeated 2 times.
# ID: 48525, Repeated 2 times.
# ID: 48650, Repeated 2 times.
# ID: 48671, Repeated 2 times.
# ID: 48706, Repeated 2 times.
# ID: 48921, Repeated 2 times.
# ID: 48922, Repeated 2 times.
# ID: 48168, Repeated 2 times.
# ID: 48629, Repeated 2 times.
# ID: 48968, Repeated 2 times.

# %%
len(repeated_ids)
# Out:
# 3008

# %% [markdown]
# So, __3008__ IDs have repeatition that means
# - They are contributing to __2 X 3008__ = __6016__ rows,
# - If the extra row per id is a duplicate, then there are in total __3008__ extra rows which are copy of some other row.
#
# Therefore, the count of unique IDs should match the number of rows in a dataframe where we drop the duplicate rows.
# __14016__ - __3008__ = __11008__
#
# Let's, assume that the repeated ID's rows are similar, and if we drop the duplicate rows from the data frame and check the unique values in the ID's then we should get the value as __11008__.

# %%
# droppigng the duplicate values from the original data frame and saving it in df2
df2=df.copy()
df2=df2.drop_duplicates()
len(df2)
# Out:
# 11008

# %%
len(df)
# Out:
# 14016

# %% [markdown]
# Hence, our assumption is true most of the IDs that are repeated have the same rows which basically means the data has duplicate rows and we have unique IDs for each customer.

# %% [markdown]
# #### 2. __TARGET: Indicator of customer buying the new product (N = no, Y = yes)__
#
# - Let's verify if the __TARGET attribute__ data is __N or Y__ as given in the data description and check for null values.

# %%
# extracting the unique values in the TARGET variable
df['TARGET'].unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %% [markdown]
# - Here, It is confirmed that our data matches its description and it doesn't has any null values.
# - It's data type is object which means it is a categorical variable.

# %% [markdown]
# #### 3.  __Loyalty: Customer loyalty level, from low to high (0 to 3), 99 = unclassified__
#
# - Let's verify if the __Loyalty__ attribute data is from __0 to 3 or 99__ as given in the data description and check for null values.

# %%
# extracting the unique values in the loyalty variable
df['loyalty'].unique()
# Out:
# array([99,  1,  3,  2,  0], dtype=int64)

# %% [markdown]
# - Here, It is confirmed that our data matches its description and it doesn't have any null values.
# - Even though the data type of __Loyalty__ is considered an integer because of the numerical data values it belongs to the __categorical variable__.

# %% [markdown]
# #### 4.  Age: Customer age in years

# %%
# extracting the unique values in the age variable
df['age'].unique()
# Out:
# array([ 66,  45,  42,  31,  62,  24,  57,  32,  28,  30,  44,  36,  38,
#         34,  51,  27,  56,  48,  54,  61,  37,  49,  23,  43,  70,  25,
#         35,  60,  41,  39,  47,  33,  40,  46,  76,  68,  26,  50,  53,
#         55,  52,  29,  64,  74,  69,  59,  67,  71,  65,  63,  80,  58,
#         93,  75,  79,  88,  89,  72,  91,  73,  83,  77,  78,  84,  94,
#         85,  82,  90,  86, 102,  14,  22,   5, 100,  21,  13,  87,  17,
#         81,  15,  11,  10,  92,  18,  12,  19], dtype=int64)

# %% [markdown]
# - Here, we can see that some customer's age is recorded as __5, 11, 12, and 15__ we __assume__ these might be __outliers__ because these customers are too young to purchase a product.
# - It is a Numerical variable.

# %% [markdown]
# #### 5. City: Unique code per city (where the customer resides)
#
# - Many customers can come from one city as the customers and cities have many to one relationship the city code might not be unique for various customers.
# - For, this let's check whether we have null values or not and look for some outliers.

# %%
# extracting the unique values in the city variable
df['city'].unique()
# Out:
# array([      2,       5,       4,       1,       0,       7,       6,
#              9,      11,       8,      14,      15,      12,     116,
#             13,     111,      10,       3,     114,     142, -999999,
#            229,     178,     110,     177,     137,      17,     148,
#            122,      22,      58,     121,     127,      33,     125,
#            209,      72,      31,      51,      16,     107,     174,
#            141,     191,     104,     129,      18,      49,      73,
#             94,     131,     219,     187,      28,      89,     115,
#             53,     126,      47,      84,     235,     161,     197,
#             23,      30], dtype=int64)

# %% [markdown]
# As we can see there are no null values but we can see that there is a city code as __-999999__ but that is not possible as the city codes can not be negative and the number of digits in that is __6__ which is not possible to be either.
# - So, we consider __-999999__  as an __outlier__ over here.
# - It is a __Categorical variable__ but due to the presence of the numbers it is considered as the integer data type.

# %% [markdown]
# #### 6. Age_p: Age of customer’s partner in years
#
# - Over here it is stated as Customer's partner so the age should be 18 or above. If any value is detected below 18 it can be considered as an outlier.

# %%
# extracting the unique values in the age_P variable
df['age_P'].unique()
# Out:
# array([ 66,  45,  42,  31,  62,  24,  57,  32,  28,  30,  44,  36,  38,
#         34,  51,  27,  56,  48,  54,  61,  37,  49,  23,  43,  70,  25,
#         35,  60,  41,  39,  47,  33,  40,  46,  76,  68,  26,  50,  53,
#         55,  52,  29,  64,  74,  69,  59,  67,  71,  65,  63,  80,  58,
#         93,  75,  79,  88,  89,  72,  91,  73,  83,  77,  78,  84,  94,
#         85,  82,  90,  86, 102,  14,  22,   5, 100,  21,  13,  87,  17,
#         81,  15,  11,  10,  92,  18,  12,  19], dtype=int64)

# %% [markdown]
# - Here, we can see that the data is similar to that of age attribute.
# - There are no null values in these.
# - But we can spot some __outliers__ here as the __partners age__ group is given as __5,11,12,15__ which is not possible.
# - It is a Numerical variable.

# %% [markdown]
# #### 7. LOR_m: Length of customer’s relationship with company (in months)

# %%
# extracting the unique values in the lor_M variable
df['lor_M'].unique()
# Out:
# array([ 3, 39, 27, 15, 63, 51, 75], dtype=int64)

# %% [markdown]
# - We have no null values here.
# - The length of relationship between the customers and the company ranges from 3 to 75 months.
# - It belongs to Numerical variable and integer data type.

# %% [markdown]
# #### 8. Prod_A and Prod_B : Customer previously bought Product A (0=no, 1=yes) and Customer previously bought Product B (0=no, 1=yes)

# %%
# extracting the unique values in the prod_A variable
df['prod_A'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
# extracting the unique values in the prod_B variable
df['prod_B'].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# - Here, It is confirmed that our data of both __prod_A and prod_B__ matches its description and it doesn't have any null values.
# - Even though the data type of __prod_A and prod_B__ is considered an integer because of the numerical data values it belongs to the __categorical variable__.

# %% [markdown]
# #### 9. Type_A and Type_B : Type of product A and Type of product B

# %%
# extracting the unique values in the type_A variable
df['type_A'].unique()
# Out:
# array([0, 3, 6], dtype=int64)

# %%
# extracting the unique values in the type_B variable
df['type_B'].unique()
# Out:
# array([0, 3, 6, 9], dtype=int64)

# %% [markdown]
# - Here, It is confirmed that our data of both __type_A and type_B__ matches its description and it doesn't have any null values.
# - Even though the data type of __type_A and type_B__ is considered an integer because of the numerical data values it belongs to the __categorical variable__.

# %% [markdown]
# #### 10. Turnover_A and Turnover_B : Amount of money customer spent on Product A and Amount of money customer spent on Product B

# %%
# checking for the null values in the turnover_A variable
df['turnover_A'].isnull().sum()
# Out:
# 0

# %%
# looking over the data type of the turnover_A variable
df['turnover_A'].dtype
# Out:
# dtype('float64')

# %%
# checking for the null values in the turnover_B variable
df['turnover_B'].isnull().sum()
# Out:
# 0

# %%
# looking over the data type of the turnover_B variable
df['turnover_A'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# - Here, It is confirmed that our data of both __turnover_A and turnover_B__ matches its description and it doesn't have any null values.
# - Both __turnover_A and turnover_B__ are numerical variable and is of floating point data.

# %% [markdown]
# Hence, the data confirms the dictionary.

# %% [markdown]
# ---------------------------------------------------
# ### 4.Creation of DataFrame subset

# %%
# Apart from existing columns I'm choosing 'turnover_A' and 'turnover_B' as per the assingment demands 
sub_df= df[['TARGET','age','type_A','type_B','lor_M','turnover_A','turnover_B']]
sub_df
# Out:
#       TARGET  age  type_A  type_B  lor_M  turnover_A   turnover_B
# 0          Y   66       0       0      3  333.561114   264.721010
# 1          Y   45       3       3     39  394.735699   284.904978
# 2          Y   42       3       6     27  342.180990  1175.589721
# 3          Y   31       0       0      3  453.757916   242.341754
# 4          Y   62       0       0      3  384.577469   287.008370
# ...      ...  ...     ...     ...    ...         ...          ...
# 14011      Y   30       0       0      3  386.434278   284.309508
# 14012      Y   27       3       3     27  376.842591   266.993794
# 14013      Y   26       0       0      3  434.805703   284.629361
# 14014      Y   75       3       3     15  366.273857   270.573265
# 14015      Y   61       0       0      3  445.059067   217.425934
#
# [14016 rows x 7 columns]

# %%
# using replace() for replacing the data values of Y and N as 1 and 0
sub_df['TARGET'] = sub_df['TARGET'].replace({'Y': 1, 'N': 0})
sub_df
# Out:
#        TARGET  age  type_A  type_B  lor_M  turnover_A   turnover_B
# 0           1   66       0       0      3  333.561114   264.721010
# 1           1   45       3       3     39  394.735699   284.904978
# 2           1   42       3       6     27  342.180990  1175.589721
# 3           1   31       0       0      3  453.757916   242.341754
# 4           1   62       0       0      3  384.577469   287.008370
# ...       ...  ...     ...     ...    ...         ...          ...
# 14011       1   30       0       0      3  386.434278   284.309508
# 14012       1   27       3       3     27  376.842591   266.993794
# 14013       1   26       0       0      3  434.805703   284.629361
# 14014       1   75       3       3     15  366.273857   270.573265
# 14015       1   61       0       0      3  445.059067   217.425934
#
# [14016 rows x 7 columns]

# %% [markdown]
# ---------------------------------------------------
# ### 5.Exploratory Data Analysis

# %%
sub_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14016 entries, 0 to 14015
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   TARGET      14016 non-null  int64
#  1   age         14016 non-null  int64
#  2   type_A      14016 non-null  int64
#  3   type_B      14016 non-null  int64
#  4   lor_M       14016 non-null  int64
#  5   turnover_A  14016 non-null  float64
#  6   turnover_B  14016 non-null  float64
# dtypes: float64(2), int64(5)
# memory usage: 766.6 KB

# %% [markdown]
# - __sub_df.info()__ function provides a concise summary of the DataFrame, that includes the information about the RangeIndex, Data column, Column names their non-null values count, and data types of each column.
#
# Although the above information indicates that columns such as __Type_A, and Type_B__ are classified as integer data types, they fall under __categorical data__.

# %%
sub_df.isnull().sum()
# Out:
# TARGET        0
# age           0
# type_A        0
# type_B        0
# lor_M         0
# turnover_A    0
# turnover_B    0
# dtype: int64

# %% [markdown]
# There are no null vales in the data.

# %% [markdown]
# #### Summary Statistics of Numerical Data:
# 1. Age
# 2. LOR_m
# 3. Turnover_A
# 4. Turnover_B

# %%
sub_df[['age','lor_M','turnover_A','turnover_B']].describe()
# Out:
#                 age         lor_M    turnover_A    turnover_B
# count  14016.000000  14016.000000  14016.000000  14016.000000
# mean      35.882920     14.115582    379.161320    328.628207
# std       12.974634     11.582550     92.612207    475.616525
# min        5.000000      3.000000    300.095909    191.962852
# 25%       25.000000      3.000000    334.919412    219.406925
# 50%       33.000000     15.000000    367.891493    237.656757
# 75%       43.000000     15.000000    399.744924    264.131538
# max      102.000000     75.000000   5568.784139  12249.084770

# %% [markdown]
# 1. __age__:
#
# - Count: There are 14,016 non-null values for age.
# - Mean: The average age is approximately 35.88 years.
# - Standard Deviation: The spread of ages around the mean is 12.97 years.
# - Minimum: The youngest age observed is 5 years. This might be an outlier.
# - 25%: 25% of the customers are the age of 25 years.
# - Median/50%: 50% of customers are the age of 33 years.
# - 75%: 75% of customers are the age of 43 years.
# - Maximum: The oldest age observed is 102 years.
#
# 2. __lor_M__:
#
# - Count: There are 14,016 non-null values for lor_M.
# - Mean: The average length of the relationship of the customers with the company is 14.11 months.
# - Std: The spread of lengths of relationship around the mean is 11.58 months.
# - Min: The shortest length of the relationship observed is 3 months.
# - 25%: 25% of the customers have a relationship length of 3 months.
# - Median/ 50%: 50% of the customers have a relationship length of 15 months.
# - 75%: 75% of the customers have a relationship length of 15 months.
# - Max: The longest length of the relationship observed is 75 months.
#
# 3. __turnover_A__:
#
# - Count: There are 14,016 non-null values for turnover_A.
# - Mean: The average turnover for Product A is 379.16.
# - Std: The spread of turnover values around the mean is 92.61.
# - Min: The lowest turnover observed for Product A is 300.10.
# - 25%: 25% of the customers have a turnover for Product A is 334.92.
# - Median: 50% of the customers have a turnover for Product A is 367.89.
# - 75%: 75% of the customers have a turnover for Product A is 399.74.
# - Max: The highest turnover observed for Product A is 5568.78.
#
# 4. __turnover_B__:
#
# - Count: There are 14,016 non-null values for turnover_B.
# - Mean: The average turnover for Product A is 328.62.
# - Std: The spread of turnover values around the mean is 475.61.
# - Min: The lowest turnover observed for Product A is 191.96.
# - 25%: 25% of the customers have a turnover for Product A is 219.40.
# - Median: 50% of the customers have a turnover for Product A is 237.65.
# - 75%: 75% of the customers have a turnover for Product A is 264.13.
# - Max: The highest turnover observed for Product A is 12249.08.

# %% [markdown]
# #### Univariate Analysis  of Numerical Data:
#
# #### 1. Age:

# %%
# Set style
sns.set_style("whitegrid")

# Set up the figure and axes
fig, ax = plt.subplots(1, 2, figsize=(10, 6))

var = 'age'

# Box plot
sns.boxplot(x=var, data=sub_df, ax=ax[0], color='skyblue', linewidth=1.5)
ax[0].set_title(f'Distribution of {var}', fontsize=16)
ax[0].set_xlabel('age', fontsize=14)
ax[0].set_ylabel('')

# Histogram
sns.histplot(sub_df[var], kde=True, ax=ax[1], color='skyblue', linewidth=1.5)
ax[1].set_title(f'Distribution of {var}', fontsize=16)
ax[1].set_xlabel('age', fontsize=14)
ax[1].set_ylabel('Frequency', fontsize=14)

# Add mean line to histogram
mean_height = np.nanmean(sub_df[var])
ax[1].axvline(x=mean_height, color='red', linestyle='--', label=f'Mean: {mean_height:.2f}')
ax[1].legend(fontsize=12)

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# The summary statistics, histogram, and boxplot show that the distribution of the __Age__ attribute is significantly __right-skewed__, with a __mean value (35.88)__ that exceeds the median. From the box plot, we can guess the __median value as 33__. The summary statistics also show that nearly __25%__ of the observation values of __age__ fall between __5 to 23__ and the majority of the customers fall under the age groups of __25 to 42__. Both the histogram and the boxplot show evidence of possible outliers, i.e., __age__ values that fall far beyond the upper whisker of the distribution as shown in the boxplot.

# %% [markdown]
# #### 2. lor_M :

# %%
# Set style
sns.set_style("whitegrid")

# Set up the figure and axes
fig, ax = plt.subplots(1, 2, figsize=(10, 6))

var = 'lor_M'

# Box plot
sns.boxplot(x=var, data=sub_df, ax=ax[0], color='skyblue', linewidth=1.5)
ax[0].set_title(f'Distribution of {var}', fontsize=16)
ax[0].set_xlabel('lor_M', fontsize=14)
ax[0].set_ylabel('')

# Histogram
sns.histplot(sub_df[var], kde=True, ax=ax[1], color='skyblue', linewidth=1.5)
ax[1].set_title(f'Distribution of {var}', fontsize=16)
ax[1].set_xlabel('lor_M', fontsize=14)
ax[1].set_ylabel('Frequency', fontsize=14)

# Add mean line to histogram
mean_height = np.nanmean(sub_df[var])
ax[1].axvline(x=mean_height, color='red', linestyle='--', label=f'Mean: {mean_height:.2f}')
ax[1].legend(fontsize=12)

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# The summary statistics, histogram, and boxplot show that the distribution of the __lor_M__ attribute is significantly __right-skewed__, with a __mean value (14.12)__ and we can see that it is __mutlimodal__ .The majorty of the customers have __lor_M__ between __3 and 15__. Both the histogram and the boxplot show evidence of possible outliers, i.e., __lor_M__ values that fall far beyond the upper whisker of the distribution as shown in the boxplot.

# %% [markdown]
# #### 3. turnover_A:

# %%
# Set style
sns.set_style("whitegrid")

# Set up the figure and axes
fig, ax = plt.subplots(1, 2, figsize=(10, 6))

var = 'turnover_A'

# Box plot
sns.boxplot(x=var, data=sub_df, ax=ax[0], color='skyblue', linewidth=1.5)
ax[0].set_title(f'Distribution of {var}', fontsize=16)
ax[0].set_xlabel('turnover_A', fontsize=14)
ax[0].set_ylabel('')

# Histogram
sns.histplot(sub_df[var], kde=True, ax=ax[1], color='skyblue', linewidth=1.5)
ax[1].set_title(f'Distribution of {var}', fontsize=16)
ax[1].set_xlabel('turnover_A', fontsize=14)
ax[1].set_ylabel('Frequency', fontsize=14)

# Add mean line to histogram
mean_height = np.nanmean(sub_df[var])
ax[1].axvline(x=mean_height, color='red', linestyle='--', label=f'Mean: {mean_height:.2f}')
ax[1].legend(fontsize=12)

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# The summary statistics, histogram, and boxplot show that the distribution of the __turnover_A__ attribute is significantly __right-skewed__, with a __mean value (379.16)__. The summary statistics also shows that the majority of the customers have spent around __300 to 500__ on product A. Both the histogram and the boxplot show evidence of possible outliers, i.e., __turnover_A__ values that fall far beyond the upper whisker of the distribution as shown in the boxplot.

# %% [markdown]
# #### 4. turnover_B

# %%
# Set style
sns.set_style("whitegrid")

# Set up the figure and axes
fig, ax = plt.subplots(1, 2, figsize=(10, 6))

var = 'turnover_B'

# Box plot
sns.boxplot(x=var, data=sub_df, ax=ax[0], color='skyblue', linewidth=1.5)
ax[0].set_title(f'Distribution of {var}', fontsize=16)
ax[0].set_xlabel('turnover_B', fontsize=14)
ax[0].set_ylabel('')

# Histogram
sns.histplot(sub_df[var], kde=True, ax=ax[1], color='skyblue', linewidth=1.5)
ax[1].set_title(f'Distribution of {var}', fontsize=16)
ax[1].set_xlabel('turnover_B', fontsize=14)
ax[1].set_ylabel('Frequency', fontsize=14)

# Add mean line to histogram
mean_height = np.nanmean(sub_df[var])
ax[1].axvline(x=mean_height, color='red', linestyle='--', label=f'Mean: {mean_height:.2f}')
ax[1].legend(fontsize=12)

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# The summary statistics, histogram, and boxplot show that the distribution of the __turnover_B__ attribute is significantly __right-skewed__, with a __mean value (328.63)__. The summary statistics also shows that the majority of the customers have spent around __100 to 300__ on product B. Both the histogram and the boxplot show evidence of possible outliers, i.e., __turnover_B__ values that fall far beyond the upper whisker of the distribution as shown in the boxplot.

# %% [markdown]
# #### Summary Statistics of Categorical Data:
# 1. TARGET
# 2. type_A
# 3. type_B

# %%
sub_df[['TARGET','type_A','type_B']].astype("object").describe()
# Out:
#         TARGET  type_A  type_B
# count    14016   14016   14016
# unique       2       3       4
# top          0       3       3
# freq      8000    7452    7874

# %% [markdown]
# 1. __TARGET__:
#
# - Count: There are 14,016 non-null values for TARGET.
# - unique: the no of unique values are 2.
# - top: The value which has the highest frequency is __0__.
# - freq: The frequency of the top value is __8000__.
#
# 2. __type_A__:
#
# - Count: There are 14,016 non-null values for type_A.
# - unique: the no of unique values are 3.
# - top: The value which has the highest frequency is __3__.
# - freq: The frequency of the top value is __7452__.
#
# 3. __type_B__:
#
# - Count: There are 14,016 non-null values for type_B.
# - unique: the no of unique values are 4.
# - top: The value which has the highest frequency is __8__.
# - freq: The frequency of the top value is __7874__.

# %% [markdown]
# #### Univariate Analysis  of Categorical Data:

# %% [markdown]
# #### 1. TARGET

# %%
palette = sns.color_palette("viridis", len(sub_df['TARGET'].value_counts()))

# Mapping the 'TARGET' values to colors
value_counts = sub_df['TARGET'].value_counts()
colors = {value: palette[i] for i, value in enumerate(value_counts.index)}

# Plotting the distribution of 'TARGET' with the fixed palette
plt.figure(figsize=(6,4))
sns.countplot(x='TARGET', data=sub_df, palette=colors)
plt.title('TARGET', fontsize=16)
plt.xlabel('Y/N', fontsize=14)  # Add x-axis label
plt.ylabel('Frequency', fontsize=14)  # Add y-axis label
plt.show()

# %% [markdown]
# The results show us that there are 2 unique values within the __TARGET__ attribute.The data dictionary lists ('N' = No = 0; 'Y' = Yes = 1). The summary statistics, Bar graph shows that frequency of the customers who didn't purchase the new product is high in the __TARGET__ attribute.

# %% [markdown]
# #### 2. type_A

# %%
palette = sns.color_palette("viridis", len(sub_df['type_A'].value_counts()))

# Mapping the 'type_A' values to colors
value_counts = sub_df['type_A'].value_counts()
colors = {value: palette[i] for i, value in enumerate(value_counts.index)}
    
# Plotting the distribution of 'type_A' with the fixed palette
plt.figure(figsize=(20,15))
sns.countplot(x='type_A', data=sub_df, palette=colors)

# Annotate each bar with the count value
for p in plt.gca().patches:
    plt.gca().annotate(int(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), 
                       ha='center', va='center', fontsize=12, color='black', xytext=(0, 5), 
                       textcoords='offset points')
    
plt.title('type_A', fontsize=16)
plt.xlabel('types', fontsize=14)  # Add x-axis label
plt.ylabel('Frequency', fontsize=14)  # Add y-axis label

# Set the y-axis ticks to 100's
plt.yticks(range(0, max(value_counts)+1 , 100))

plt.show()

# %% [markdown]
# The results show us that there are 3 unique values within the __type_A__ attribute.The data dictionary lists ('0','3' and '6'). The summary statistics, Bar graph shows that frequency of the customers who purchased the product type _3_ is the highest in the __type_A__ attribute and product type _6_ is purchased by very few customers.

# %%
palette = sns.color_palette("viridis", len(sub_df['type_B'].value_counts()))

# Mapping the 'type_B' values to colors
value_counts = sub_df['type_B'].value_counts()
colors = {value: palette[i] for i, value in enumerate(value_counts.index)}

# Plotting the distribution of 'type_B' with the fixed palette
plt.figure(figsize=(20,15))
sns.countplot(x='type_B', data=sub_df, palette=colors)

# Annotate each bar with the count value
for p in plt.gca().patches:
    plt.gca().annotate(int(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), 
                       ha='center', va='center', fontsize=12, color='black', xytext=(0, 5), 
                       textcoords='offset points')
    
plt.title('type_B', fontsize=16)
plt.xlabel('types', fontsize=14)  # Add x-axis label
plt.ylabel('Frequency', fontsize=14)  # Add y-axis label

# Set the y-axis ticks to 100's
plt.yticks(range(0, max(value_counts) + 1, 100))

plt.show()

# %% [markdown]
# The results show us that there are 4 unique values within the __type_B__ attribute.The data dictionary lists ('0','3','6' and '9'). The summary statistics, Bar graph shows that frequency of the customers who purchased the product type _3_ is the highest in the __type_A__ attribute and product type _9_ is purchased by very few customers.

# %% [markdown]
# #### Bivariate Analysis
# #### 1. TARGET(Categorical)  vs.  Age(Numerical)

# %%
# Set the figure size
plt.figure(figsize=(10, 6))

# Plotting the bivariate analysis
sns.boxplot(x='TARGET', y='age', data=sub_df, palette='coolwarm')
plt.title('Bivariate Analysis: TARGET vs. Age', fontsize=16)
plt.xlabel('TARGET Products Purchase', fontsize=14)
plt.ylabel('age', fontsize=14)
#plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent overlapping
plt.show()

# %% [markdown]
# Summary Statistics and Insights from Plot:
#
# 1. Customers who didn’t purchase the new product (0):
# - The __median__ age is around __27__.
# - The majority of customers ages fall between __22 and 40__.
# - The __outliers__ are up to the age of __102__.
# 2. Customers who purchased the new product (1):
# - The __median__ age is slightly higher compared to the median age of the customers who didn't purchase the product, around __38__.
# - The majority of customers ages fall between __30 and 50__.
# - The outliers are less compared to the customers who didn't purchse the product.
#
# The boxplot shows evidence of a huge number of possible outliers, i.e., __age__ values that fall far beyond the upper whisker of the distribution as shown in the boxplot.
#
# Over here we come to an inference that the Older customers are showing mostly interested in purchasing the new products.
# However, it is clearly visible that the age groups of the customers who are purchasing and not purchasing products are overlapped. This indicates that age alone might not be sufficient to make the prediction whether the customer will take the new product or not.

# %% [markdown]
# #### 2. TARGET(Categorical)  vs.  type_A(Categorical)

# %%
CrosstabResult=pd.crosstab(index=sub_df['TARGET'],columns=sub_df['type_A'])

CrosstabResult.plot.bar(figsize=(20,18), rot=0)

# Annotate each bar with the count value
for p in plt.gca().patches:
    plt.gca().annotate(int(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), 
                       ha='center', va='center', fontsize=12, color='black', xytext=(0, 5), 
                       textcoords='offset points')
    

plt.title('TARGET vs type_A', fontsize=16)
plt.xlabel('Target purchase result', fontsize=12)
plt.ylabel('Frequency', fontsize=14)

# Set the y-axis ticks to 100's
plt.yticks(range(0, max(value_counts) + 1, 100))

# Set the y-axis limit to 5500
plt.ylim(0, 5500)

plt.tight_layout()
plt.show()

# %% [markdown]
# Summary Statistics and Insights from Plot:
#
# 1. Customers who didn’t purchase the new product (0):
# - The __type 3 products__ are purchased most here followed by the __type 0__.
# - The purchase of type 3 products is more than double the purchase of type 0 products.
# - The type 6 product has the least significance in this.
# 2. Customers who purchased the new product (1):
# - The __type 0 products__ are purchased most here followed by the __type 3__.
# - The purchase of type 0 products is almost double the purchase of type 0 products.
# - The type 6 product has the least significance in this.
#
# Over here we come to an inference that the customers who purchased __type 3__ products might not be satisfied and are not purchasing the new product. Where as, on the other hand customers who purchased more number of __type 0__ products are showing more interest in purchasing the new products.

# %% [markdown]
# #### 3. TARGET(Categorical)  vs.  type_B(Categorical)

# %%
CrosstabResult=pd.crosstab(index=sub_df['TARGET'],columns=sub_df['type_B'])

CrosstabResult.plot.bar(figsize=(20,18), rot=0)

# Annotate each bar with the count value
for p in plt.gca().patches:
    plt.gca().annotate(int(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()), 
                       ha='center', va='center', fontsize=12, color='black', xytext=(0, 5), 
                       textcoords='offset points')
    

plt.title('TARGET vs type_B', fontsize=16)
plt.xlabel('Target purchase result', fontsize=12)
plt.ylabel('Frequency', fontsize=14)

# Set the y-axis ticks to 100's
plt.yticks(range(0, max(value_counts) + 1, 100))

# Set the y-axis limit to 5500
plt.ylim(0, 5500)

plt.tight_layout()
plt.show()

# %% [markdown]
# Summary Statistics and Insights from Plot:
#
# 1. Customers who didn’t purchase the new product (0):
# - The __type 3 products__ are purchased most here followed by the __type 0__.
# - The purchase of type 3 products is more than double the purchase of type 0 products.
# - The type 6 and 9 products has the least significance in this.
# 2. Customers who purchased the new product (1):
# - The __type 0 products__ are purchased most here followed by the __type 3__.
# - The type 6 and 9 products has the least significance in this.
#
# Over here we come to an inference that the customers who purchased __type 3__ products might not be satisfied and are not purchasing the new product. Where as, on the other hand customers who purchased more number of __type 0__ products are showing more interest in purchasing the new products.

# %% [markdown]
# #### 4. TARGET(Categorical)  vs.  lor_M(Numerical)

# %%
# Set the figure size
plt.figure(figsize=(10, 6))

# Plotting the bivariate analysis
sns.boxplot(x='TARGET', y='lor_M', data=sub_df, palette='coolwarm')
plt.title('Bivariate Analysis: TARGET vs. lor_M', fontsize=16)
plt.xlabel('TARGET Products Purchase', fontsize=14)
plt.ylabel('lor_M', fontsize=14)
#plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent overlapping
plt.show()

# %% [markdown]
# Summary Statistics and Insights from Plot:
#
# 1. Customers who didn’t purchase the new product (0):
# - It has so many outliers.
# - The data values are mostly focused/spread on one value which is around __15__.
# - We can see no spread of data and no whiskers over here.
# 2. Customers who purchased the new product (1):
# - The outliers are less compared to the customers who didn't purchase the new product.
# - The majority of customers have __3 to 15 months__ of relationship with the company.
# - The Upper whisker runs upto __28 months__.
#
# Over here we come to an inference that the customers with a relationship length of __3 to 15 months__ are mostly interested in purchasing the new products. This indicates that the length of the relationship might be sufficient to make the prediction.

# %% [markdown]
# #### 5. TARGET(Categorical)  vs.  turnover_A(Numerical)

# %%
# Set the figure size
plt.figure(figsize=(20,15))

# Plotting the bivariate analysis
sns.boxplot(x='TARGET', y='turnover_A', data=sub_df, palette='coolwarm')
plt.title('Bivariate Analysis: TARGET vs. turnover_A', fontsize=16)
plt.xlabel('TARGET Products Purchase', fontsize=14)
plt.ylabel('turnover_A', fontsize=14)

# Set the y-axis ticks to 100's
plt.yticks(range(0, max(value_counts) + 1, 100))

# Set the y-axis limit to 5500
plt.ylim(0, 5700)

plt.tight_layout()  # Adjust layout to prevent overlapping
plt.show()

# %% [markdown]
# Summary Statistics and Insights from Plot:
#
# 1. Customers who didn’t purchase the new product (0):
# - It has many outliers and it ranges from __460 to 5600__ turnover.
# - The data values are mostly focused/spread around __350 to 390__ turnover.
# - We can see the spread of data and whiskers around __300 to 490__ turnover.
# 2. Customers who purchased the new product (1):
# - The outliers and its spread is less compared to the customers who didn't purchase the new product.
# - The majority of customers have made __350 to 450 turnover__ for the company.
# - We can see the spread of data and whiskers around __300 to 600__ turnover.
#
# Over here we come to an inference that the customers who spent more on the product A are most likely to purchase the new product.

# %% [markdown]
# #### 6. TARGET(Categorical)  vs.  turnover_B(Numerical)

# %%
# Set the figure size
plt.figure(figsize=(20, 15))

# Plotting the bivariate analysis
sns.boxplot(x='TARGET', y='turnover_B', data=sub_df, palette='coolwarm')
plt.title('Bivariate Analysis: TARGET vs. turnover_B', fontsize=16)
plt.xlabel('TARGET Products Purchase', fontsize=14)
plt.ylabel('turnover_B', fontsize=14)

# Set the y-axis ticks to 100's
plt.yticks(range(0, max(value_counts) + 1, 100))

# Set the y-axis limit to 5500
plt.ylim(0, 5700)

plt.tight_layout()  # Adjust layout to prevent overlapping
plt.show()

# %% [markdown]
# Summary Statistics and Insights from Plot:
#
# 1. Customers who didn’t purchase the new product (0):
# - It has many outliers and it ranges from __300 to 5700__ turnover.
# - The data values are mostly focused/spread around __210 to 250__ turnover.
# - We can see the spread of data and whiskers around __200 to 300__ turnover.
# 2. Customers who purchased the new product (1):
# - The outliers and its spread is less compared to the customers who didn't purchase the new product.
# - The majority of customers have made __220 to 380 turnover__ for the company.
# - We can see the spread of data and whiskers around __200 to 350__ turnover.
#
# Over here we come to an inference that the customers who spent more on the product B are most likely to purchase the new product.

# %% [markdown]
# --------------------------------------------
# ### 6. Preliminary Conclusions:
#
# The __turnover_A__ and __turnover_B__ columns might be helpful in n predicting whether a specific customer is likely to purchase an additional product. When a customer spends his amount on the product and if the customer is satisfied with it he will purchase that particular product again hence the turnover of that product increases. Then automatically the customer will show his interest in the new product and there would be higher chances of him purchasing the new product. Hence, accordingly the probability of the customer purchasing the new product increases. Thus, aside from __TARGET__, we can use __turnover_A__ and __turnover_B__ for the prediction of customer behavior.

# %% [markdown]
# -------------------------------------------------
# ### 7.  Feature Engineering
#
# -  __We create a dummy indicator for both 'Type_A' and 'Type_B' categorical variable__:
# - The new dummy variables are the values in the original column with the prefix of that particular column.
# - Over here, in __type_A__ varibale we have three values __0,3 and 6__ for these three values seperate columns are created using the __get_dummies()__ in pandas.
# - Same is performed with the __type_B__ variable which has four values __0,3,6, and 9__.

# %%
dummies_A = pd.get_dummies(sub_df['type_A'], prefix='type_A',dtype=int)
dummies_B = pd.get_dummies(sub_df['type_B'], prefix='type_B',dtype=int)

# Drop the original 'Type_A' and 'Type_B' columns from df
sub_df = sub_df.drop(['type_A', 'type_B'], axis=1)

# Concatenate the original DataFrame with the dummy DataFrame
sub_df_dummy = pd.concat([sub_df, dummies_A, dummies_B], axis=1)
sub_df_dummy
# Out:
#        TARGET  age  lor_M  turnover_A   turnover_B  type_A_0  type_A_3  \
# 0           1   66      3  333.561114   264.721010         1         0
# 1           1   45     39  394.735699   284.904978         0         1
# 2           1   42     27  342.180990  1175.589721         0         1
# 3           1   31      3  453.757916   242.341754         1         0
# 4           1   62      3  384.577469   287.008370         1         0
# ...       ...  ...    ...         ...          ...       ...       ...
# 14011       1   30      3  386.434278   284.309508         1         0
# 14012       1   27     27  376.842591   266.993794         0         1
# 14013       1   26      3  434.805703   284.629361         1         0
# 14014       1   75     15  366.273857   270.573265         0         1
# 14015       1   61      3  445.059067   217.425934         1         0
#
#        type_A_6  type_B_0  type_B_3  type_B_6  type_B_9
# 0             0         1         0         0         0
# 1             0         0         1         0         0
# 2             0         0         0         1         0
# 3             0         1         0         0         0
# 4             0         1         0         0         0
# ...         ...       ...       ...       ...       ...
# 14011         0         1         0         0         0
# 14012         0         0         1         0         0
# 14013         0         1         0         0         0
# 14014         0         0         1         0         0
# 14015         0         1         0         0         0
#
# [14016 rows x 12 columns]

# %%
#Dropping dummy variables
sub_df_dummy=sub_df_dummy.drop_duplicates()

# %%
len(sub_df_dummy)
# Out:
# 11008

# %%
#checking for null values
sub_df_dummy.isnull().sum()
# Out:
# TARGET        0
# age           0
# lor_M         0
# turnover_A    0
# turnover_B    0
# type_A_0      0
# type_A_3      0
# type_A_6      0
# type_B_0      0
# type_B_3      0
# type_B_6      0
# type_B_9      0
# dtype: int64

# %% [markdown]
# ## Phase II: Build Predictive Models
# ### Model 1: Using LogisticRegression with *age, type_A, type_B, lor_M, turnover_A, turnover_B, type_A_0, type_A_3, type_A_6, type_B_0, type_B_3, type_B_6, and type_B_9*

# %% [markdown]
# Our goal is to __try to predict whether our customer will purchase a new product or not__ based on the data contained in the data set (i.e., build a __predictive model__).
#
# - First, we will split our data set into __training__ and __testing__ data set.
#
# - Then we will fit a logistic regression model on a __training__ data set using the data set's __age,lor_M, turnover_A, turnover_B, type_A_0, type_A_3, type_A_6, type_B_0, type_B_3, type_B_6, and type_B_9__ attributes.
#
# - Finally, we evaluate the model using a __testing__ data set that is exclusive of the data contained in the __training__ data set.

# %%
# load the train_test_split() function from sklearn's 'model_selection' sub-library
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix

#store explanatory and response variables in X and y respectively.
X = sub_df_dummy[['age','lor_M','turnover_A','turnover_B','type_A_0','type_A_3','type_A_6','type_B_0','type_B_3','type_B_6','type_B_9']]
y = sub_df_dummy['TARGET']

# Train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %% [markdown]
# - In __X__ we are storing the __"Explanatory" (aka "Independent") variables__ variables. Where as, in __y__ we are storing __"Response" (aka "Dependent") variable__
# - __X_train__: These are the input variables used to __train__ the __machine learning model__.
# - __X_test__: These are the input variables used to __evaluate__ the __performance__ of the trained model.
# - __y_train__: These are the known __outcomes associated with the training data__.
# - __y_test__: These are the known __outcomes used to evaluate the performance__ of the model predictions.
# - __train_test_split__: It __splits the dataset__ into random train and test subsets.
# - __test_size__: It's set to __0.25, meaning 25% of the data__ will be used for __testing__, and the remaining __75%__ will be used for __training__.

# %%
# Print sample of training and testing subsets
print("Training Subset:")
print(X_train[:4])
print(y_train[:4])

print("\nTesting Subset:")
print(X_test[:4])
print(y_test[:4])
# Out:
# Training Subset:
#       age  lor_M  turnover_A  turnover_B  type_A_0  type_A_3  type_A_6  \
# 2513   41      3  406.364004  291.035494         1         0         0
# 4210   41     15  374.788768  206.982347         0         1         0
# 1463   28      3  349.701141  287.210117         1         0         0
# 5538   30     15  358.648451  220.314538         0         1         0
#
#       type_B_0  type_B_3  type_B_6  type_B_9
# 2513         1         0         0         0
# 4210         0         1         0         0
# 1463         1         0         0         0
# 5538         0         1         0         0
# 2513    1
# 4210    0
# 1463    1
# 5538    0
# Name: TARGET, dtype: int64
#
# Testing Subset:
#       age  lor_M  turnover_A  turnover_B  type_A_0  type_A_3  type_A_6  \
# 107    32      3  498.517293  271.721931         1         0         0
# 5487   45      3  366.710581  228.517132         1         0         0
# 1870   35     15  400.375798  268.408176         0         1         0
# 4064   36     27  354.176778  220.108074         0         1         0
#
#       type_B_0  type_B_3  type_B_6  type_B_9
# 107          1         0         0         0
# 5487         1         0         0         0
# 1870         0         1         0         0
# 4064         0         1         0         0
# 107     1
# 5487    0
# 1870    1
# 4064    0
# Name: TARGET, dtype: int64

# %%
# No.of records in the y_train data set
y_train.shape
# Out:
# (8256,)

# %%
# customers who purchased the new product in the y_train data set which has target column only 
y_train.values.sum()
# Out:
# 2263

# %%
# percentage of the customers who purchased the new product
y_train.values.sum() / y_train.shape[0]
# Out:
# 0.27410368217054265

# %% [markdown]
# __NOTE__: Since we know that __27.41%__ of the customers in the training set purchased the new product, we could achieve a training model accuracy of __(1 -0.2741) = 72.59%__ by simply predicting "Did not Purchase" for each customer. This metric is referred to as the __null error rate__.  When evaluating the performance of a binary logistic regression model, always check to see whether the accuracy you are attaining exceeds the __null error rate__. If not, our model is unlikely to be of any value.
# So, according to this our model prediction accuracy should be more than 72.59%.
# - As, we have already verified that there are no null values but during the study of data we got to know that there are dummy variables in the data and we even dropped them so we can move forward with this data and build the prediction model.

# %% [markdown]
# Now we are ready to define our predictive model using the attributes we want to use as explanatory variables:

# %%
# We're using the LogisticRegression() method for this model
model = LogisticRegression()

# fit the model: X_train contains our explanatory variables while 
# y_train contains the response variable
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# calculate the accuracy of the model relative to the training data set
model.score(X_train, y_train)
# Out:
# 0.7943313953488372

# %% [markdown]
# Above we calculated the __null error rate__ for our data to be __72.59%__. The model we've generated has an accuracy score of __74.20%__. As such, our model appears to be useful.
#
#
# While the actual numeric values of the coefficients of a regression model are often very difficult to interpret, we can use the fact that a coefficient is either positive or negative to determine what effect of an __increase__ in the value of a given variable will have on the predicted value of the response variable.
#
# In this binary logistic regression example, the value of the response variable is the "log odds" of the binary outcome being either a '0' or '1' ('0' meaning the customers are more inclined towards not purchasing the new product while '1' indicates the customers are more likely to purchase the new product).

# %%
print(X_train.columns)
model.coef_
# Out:
# Index(['age', 'lor_M', 'turnover_A', 'turnover_B', 'type_A_0', 'type_A_3',
#        'type_A_6', 'type_B_0', 'type_B_3', 'type_B_6', 'type_B_9'],
#       dtype='object')
# array([[ 4.09960939e-02, -1.78318695e-03,  1.08152146e-02,
#         -2.53930668e-03, -7.99078846e-01, -2.13331725e+00,
#         -2.35390000e-01, -1.05249130e+00, -1.05547398e+00,
#         -1.02964204e+00, -3.01787770e-02]])

# %% [markdown]
# From the above we see that:
#
# - __age__: The older the customers, the more likely to purchase the new product.
#
# - __lor_M__: Customers having long relation with the company are showing less interest towards purchasing the new product.
#
# - __turnover_A__: The customers who spent higher amount on the product A are most likely to purchase.
#
# - __turnover_B__: Customers who spent higher amount on the product B are less likely to purchase.
#
# - __type_A's and type_B's__: product 6 of type A and product 3 of type B purchasing customers are less likely to purchase the new product where as remaining type of product purchased by other customers are comparetively more likely to purchase the new product.

# %%
# generate predictions for the test data using our new model
y_predict = model.predict(X_test)
y_predict
# Out:
# array([1, 1, 0, ..., 0, 0, 0], dtype=int64)

# %%
# generate class probabilities
probs = model.predict_proba(X_test)
probs
# Out:
# array([[2.84265981e-01, 7.15734019e-01],
#        [4.64922758e-01, 5.35077242e-01],
#        [7.96609930e-01, 2.03390070e-01],
#        ...,
#        [8.78663568e-01, 1.21336432e-01],
#        [7.24618863e-01, 2.75381137e-01],
#        [9.99964248e-01, 3.57524279e-05]])

# %% [markdown]
# As you can see, the classifier is predicting a 1 (Buying a new product) any time the probability in the second column is greater than 0.5.

# %%
print(classification_report(y_test, y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.94      0.87      2007
#            1       0.71      0.43      0.54       745
#
#     accuracy                           0.80      2752
#    macro avg       0.76      0.68      0.70      2752
# weighted avg       0.79      0.80      0.78      2752

# %% [markdown]
# 1. __Precision__: It measures the accuracy of the positive predictions made by the model.
#
# - _Precision for class 0 (negative class)_ : it is 0.82, which means 82% of the instances predicted as class 0 by the model are actually class 0.
# - _Precision for class 1 (positive class)_: it is 0.71, which means 71% of the instances predicted as class 1 by the model are actually class 1.
#
# 2. __Recall__: It measures the ability of the model to correctly identify positive instances out of all actual positive instances.
#
# - _Recall for class 0 (negative class)_: it is 0.94, which means the model correctly identifies 94% of the actual negative instances.
# - _Recall for class 1 (positive class)_: it is 0.43, which means the model correctly identifies 43% of the actual positive instances.
#
# 3. __F1-score__: The F1-score is the harmonic mean of precision and recall.
# - _F1-score for class 0_: it is 0.87, which indicates a good balance between precision and recall for the negative class.
# - _F1-score for class 1_: it is 0.54, which indicates a lower balance between precision and recall for the positive class.
#
# 4. __Support__: Support is the number of actual occurrences of each class in the test dataset.
#
# - _Support for class 0__: it is 2007, which means there are 2007 instances of the negative class in the test dataset.
# - _Support for class 1_: it is 745, which means there are 745 instances of the positive class in the test dataset.
#
# 5. __Accuracy__: Accuracy measures the overall correctness of the model across all classes.  the accuracy is 0.80, which means the __model correctly predicts 80% of the instances__ in the test dataset.

# %%
# generate evaluation metrics
print (metrics.accuracy_score(y_test, y_predict))
print (metrics.roc_auc_score(y_test, probs[:, 1]))
# Out:
# 0.7990552325581395
# 0.823874158565825

# %% [markdown]
# The accuracy is 79%, which is the same as we experienced when training and predicting on the same data.

# %% [markdown]
# #### Model Evaluation Using Cross-Validation
# Now let's try 10-fold cross-validation, to see if the accuracy holds up more rigorously.

# %%
# evaluate the model using 10-fold cross-validation
scores = cross_val_score(LogisticRegression(), X, y, scoring='accuracy', cv=10)
print (scores)
print (scores.mean())
# Out:
# [0.7938238  0.78655767 0.791099   0.79564033 0.79654859 0.791099
#  0.791099   0.8119891  0.80636364 0.79727273]
# 0.7961492857732639

# %% [markdown]
# Looks good. It's still performing at 79% accuracy.

# %% [markdown]
# #### Predicting the Probability of a Customer
#  let's predict the probability of a random Customer who is not present in the dataset. a customer who is 50 years old purchased product 3 of type_A and product 0 of type_B and has 15 months of relationship with the company, who spend almost 345.78 and 255.29 on turnover_A and turnover_B

# %%
# Define the features for the new customer
new_customer_features = [50, 3, 345.78, 255.29, 0, 1, 0, 1, 0, 0, 0]
# Reshape the features to match the format expected by the model 
new_customer_features_reshaped = np.array(new_customer_features).reshape(1, -1)

# Predict the probability of the new customer
probability = model.predict_proba(new_customer_features_reshaped)

print("Probability of the new customer purchasing the new product:", probability)
# Out:
# Probability of the new customer purchasing the new product: [[0.78297213 0.21702787]]

# %% [markdown]
# The predicted probability of a Customer buying a product is 21.7%

# %% [markdown]
# ### let's try to build another Predictive Model using lor_M, turnover_A and turnover_B
# ### Model 2: LogisticRegression
#
# Over here I'm particularly choosing __lor_M, turnover_A and turnover_B__ because from the __EDA of TARGET vs other vairables__ we can see that lor_M, turnover_A and turnover_B are the variables where we can clearly see that the customers who wants to purchase the new product data is relatively more and the difference is clearly seen in the box plots.
# Henceforth, I'm creating a predictive model on these three variables.

# %% [markdown]
# Our goal is to __try to predict whether our customer will purchase a new product or not__ based on the data contained in the data set (i.e., build a __predictive model__).
#
# - First, we will split our data set into __training__ and __testing__ data set.
#
# - Then we will fit a logistic regression model on a __training__ data set using the data set's __lor_M, turnover_A, turnover_B__ attributes.
#
# - Finally, we evaluate the model using a __testing__ data set that is exclusive of the data contained in the __training__ data set.

# %%
#store explanatory and response variables in X and y respectively.
X1 = sub_df_dummy[['lor_M','turnover_A','turnover_B']]
y1 = sub_df_dummy['TARGET']

# Train test split
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size=0.25, random_state=42)

# %% [markdown]
# - In __X1__ we are storing the __"Explanatory" (aka "Independent") variables__ variables. Where as, in __y1__ we are storing __"Response" (aka "Dependent") variable__
# - __X1_train__: These are the input variables used to __train__ the __machine learning model__.
# - __X1_test__: These are the input variables used to __evaluate__ the __performance__ of the trained model.
# - __y1_train__: These are the known __outcomes associated with the training data__.
# - __y1_test__: These are the known __outcomes used to evaluate the performance__ of the model predictions.
# - __train_test_split__: It __splits the dataset__ into random train and test subsets.
# - __test_size__: It's set to __0.25, meaning 25% of the data__ will be used for __testing__, and the remaining __75%__ will be used for __training__.

# %%
# Print sample of training and testing subsets
print("Training Subset:")
print(X1_train[:4])
print(y1_train[:4])

print("\nTesting Subset:")
print(X1_test[:4])
print(y1_test[:4])
# Out:
# Training Subset:
#       lor_M  turnover_A  turnover_B
# 2513      3  406.364004  291.035494
# 4210     15  374.788768  206.982347
# 1463      3  349.701141  287.210117
# 5538     15  358.648451  220.314538
# 2513    1
# 4210    0
# 1463    1
# 5538    0
# Name: TARGET, dtype: int64
#
# Testing Subset:
#       lor_M  turnover_A  turnover_B
# 107       3  498.517293  271.721931
# 5487      3  366.710581  228.517132
# 1870     15  400.375798  268.408176
# 4064     27  354.176778  220.108074
# 107     1
# 5487    0
# 1870    1
# 4064    0
# Name: TARGET, dtype: int64

# %%
# No.of records in the y1_train data set
y1_train.shape
# Out:
# (8256,)

# %%
# customers who purchased the new product in the y1_train data set which has target column only 
y1_train.values.sum()
# Out:
# 2263

# %%
# percentage of the customers who purchased the new product
y1_train.values.sum() / y1_train.shape[0]
# Out:
# 0.27410368217054265

# %% [markdown]
# __NOTE__: Since we know that __27.41%__ of the customers in the training set purchased the new product, we could achieve a training model accuracy of __(1 -0.2741) = 72.59%__ by simply predicting "Did not Purchase" for each customer. This metric is referred to as the __null error rate__.  When evaluating the performance of a binary logistic regression model, always check to see whether the accuracy you are attaining exceeds the __null error rate__. If not, our model is unlikely to be of any value.
# So, according to this our model prediction accuracy should be more than 72.59%.
# - As, we have already verified that there are no null values but during the study of data we got to know that there are dummy variables in the data and we even dropped them so we can move forward with this data and build the prediction model.

# %% [markdown]
# Now we are ready to define our predictive model using the attributes we want to use as explanatory variables:

# %%
# We're using the LogisticRegression() method for this model
model1 = LogisticRegression()

# fit the model: X_train contains our explanatory variables while 
# y_train contains the response variable
model1.fit(X1_train, y1_train)
# Out:
# LogisticRegression()

# %%
# calculate the accuracy of the model relative to the training data set
model1.score(X1_train, y1_train)
# Out:
# 0.8034156976744186

# %% [markdown]
# Above we calculated the __null error rate__ for our data to be __72.59%__. The model we've generated has an accuracy score of __80.34%__. As such, our model appears to be useful.
#
#
# While the actual numeric values of the coefficients of a regression model are often very difficult to interpret, we can use the fact that a coefficient is either positive or negative to determine what effect of an __increase__ in the value of a given variable will have on the predicted value of the response variable.
#
# In this binary logistic regression example, the value of the response variable is the "log odds" of the binary outcome being either a '0' or '1' ('0' meaning the customers are more inclined towards not purchasing the new product while '1' indicates the customers are more likely to purchase the new product).

# %%
print(X1_train.columns)
model1.coef_
# Out:
# Index(['lor_M', 'turnover_A', 'turnover_B'], dtype='object')
# array([[-0.03541138,  0.01262526, -0.00125855]])

# %% [markdown]
# From the above we see that:
#
#
# - __lor_M__: Customers having long relation with the company are showing less interest towards purchasing the new product.
#
# - __turnover_A__: The customers who spent higher amount on the product A are most likely to purchase.
#
# - __turnover_B__: Customers who spent higher amount on the product B are less likely to purchase.

# %%
# generate predictions for the test data using our new model
y1_predict = model1.predict(X1_test)
y1_predict
# Out:
# array([1, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
# generate class probabilities
probs1 = model1.predict_proba(X1_test)
probs1
# Out:
# array([[2.73625450e-01, 7.26374550e-01],
#        [6.53262846e-01, 3.46737154e-01],
#        [6.64524296e-01, 3.35475704e-01],
#        ...,
#        [7.50629538e-01, 2.49370462e-01],
#        [7.26531812e-01, 2.73468188e-01],
#        [9.99272284e-01, 7.27716311e-04]])

# %% [markdown]
# As you can see, the classifier is predicting a 1 (Buying a new product) any time the probability in the second column is greater than 0.5.

# %%
print(classification_report(y1_test, y1_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.99      0.88      2007
#            1       0.88      0.29      0.43       745
#
#     accuracy                           0.80      2752
#    macro avg       0.83      0.64      0.65      2752
# weighted avg       0.81      0.80      0.76      2752

# %% [markdown]
# 1. __Precision__: It measures the accuracy of the positive predictions made by the model.
#
# - _Precision for class 0 (negative class)_ : it is 0.79, which means 79% of the instances predicted as class 0 by the model are actually class 0.
# - _Precision for class 1 (positive class)_: it is 0.88, which means 88% of the instances predicted as class 1 by the model are actually class 1.
#
# 2. __Recall__: It measures the ability of the model to correctly identify positive instances out of all actual positive instances.
#
# - _Recall for class 0 (negative class)_: it is 0.99, which means the model correctly identifies 99% of the actual negative instances.
# - _Recall for class 1 (positive class)_: it is 0.29, which means the model correctly identifies 29% of the actual positive instances.
#
# 3. __F1-score__: The F1-score is the harmonic mean of precision and recall.
# - _F1-score for class 0_: it is 0.88, which indicates a good balance between precision and recall for the negative class.
# - _F1-score for class 1_: it is 0.43, which indicates a lower balance between precision and recall for the positive class.
#
# 4. __Support__: Support is the number of actual occurrences of each class in the test dataset.
#
# - _Support for class 0__: it is 2007, which means there are 2007 instances of the negative class in the test dataset.
# - _Support for class 1_: it is 745, which means there are 745 instances of the positive class in the test dataset.
#
# 5. __Accuracy__: Accuracy measures the overall correctness of the model across all classes.  the accuracy is 0.80, which means the __model correctly predicts 80% of the instances__ in the test dataset.

# %%
# generate evaluation metrics
print (metrics.accuracy_score(y1_test, y1_predict))
print (metrics.roc_auc_score(y1_test, probs1[:, 1]))
# Out:
# 0.7965116279069767
# 0.7623251505636314

# %% [markdown]
# The accuracy is 79%, which is the same as we experienced when training and predicting on the same data.

# %% [markdown]
# #### Model Evaluation Using Cross-Validation
# Now let's try 10-fold cross-validation, to see if the accuracy holds up more rigorously.

# %%
# evaluate the model using 10-fold cross-validation
scores1 = cross_val_score(LogisticRegression(), X1, y1, scoring='accuracy', cv=10)
print (scores1)
print (scores1.mean())
# Out:
# [0.79745686 0.80018165 0.80018165 0.80108992 0.80290645 0.80653951
#  0.80108992 0.80290645 0.81272727 0.80363636]
# 0.8028716043266451

# %% [markdown]
# Looks good. It's still performing at almost 80% accuracy.

# %% [markdown]
# #### Predicting the Probability of a Customer : Let's use the same details and then compare the two models
#  let's predict the probability of a random Customer who is not present in the dataset. a customer who is 50 years old purchased product 3 of type_A and product 0 of type_B and has 15 months of relationship with the company, who spend almost 345.78 and 255.29 on turnover_A and turnover_B

# %%
# Define the features for the new customer
new_customer_features1 = [ 3, 345.78, 255.29]
# Reshape the features to match the format expected by the model 
new_customer_features_reshaped1 = np.array(new_customer_features1).reshape(1, -1)

# Predict the probability of the new customer
probability1 = model1.predict_proba(new_customer_features_reshaped1)

print("Probability of the new customer purchasing the new product:", probability1)
# Out:
# Probability of the new customer purchasing the new product: [[0.71735141 0.28264859]]

# %% [markdown]
# The predicted probability of a Customer buying a product is 28.2%

# %% [markdown]
# ## Conclusion:
#
# - Both the models accuracy was almost same, __79%__ is the accuracy of the first model and __80%__ is the accuracy of the second model.
# - If we look at the precision of the two models we can see that for the first model the precision is mostly inclined towards the __0__ which is nothing but its inclined towards the __customer not purchasing__ the new product. Where as, the precision of the second model is inclined towards __1__ i.e, __customer purchasing__ the product.
# - Due to this even though we have very slight difference in the accuracy of the two models, the probability outcome of the new customer was predicted as __21%__ and __28%__ respectively.
# - In these two models the second model is more efficient to use as it's accuracy is more and the input data which we are giving is less compared to the input data of first model so it also takes very less time to run.
